# %% [markdown]
# # [Baseline] RandomForest — 풍력발전량 예측
#
# 기상 예보 데이터(LDAPS/GFS)로 KPX 발전그룹 3곳의 시간대별 **풍력발전량(kWh)** 을 예측하는 회귀 베이스라인입니다.
#
# - **입력**: 예측 시각별 LDAPS/GFS 기상 예보 격자 평균값 + 시간·요일·계절성 캘린더 변수
# - **출력**: `kpx_group_1/2/3` 세 발전그룹의 시간대별 예측 발전량(kWh)
# - **모델**: 그룹별 `RandomForestRegressor` (Label 제공 기간이 그룹마다 다르므로 각각 따로 학습)
#
# 이 대회는 예측 결과 CSV(`baseline_submit.csv`)를 제출하는 방식이라, 데이터 로드부터 제출 파일 생성까지
# 이 노트북 하나로 처리합니다.

# %% [markdown]
# ## 1. 라이브러리 불러오기
#
# 데이터 처리(pandas, numpy)와 회귀 모델 학습(scikit-learn)에 필요한 라이브러리를 불러옵니다.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## 2. 데이터 로드
#
# 발전량 Label(`train_labels.csv`), 제출 양식(`sample_submission.csv`), LDAPS/GFS 기상 예보 데이터를 불러오고,
# 날짜 컬럼을 datetime으로 변환합니다. `CAPACITY_KWH` 는 그룹별 설비 용량으로, 이후 예측값을 클리핑하는 데
# 사용합니다.

# %%
DATA_DIR = Path(r"C:\Users\user\iCloudDrive\riversun\동국대학교\3학년 1학기\대외활동\DACON\데이터\open")
TRAIN_DIR = DATA_DIR / "train"
TEST_DIR = DATA_DIR / "test"

TARGET_COLS = ["kpx_group_1", "kpx_group_2", "kpx_group_3"]
CAPACITY_KWH = {
    "kpx_group_1": 21600,
    "kpx_group_2": 21600,
    "kpx_group_3": 21000,
}

train_labels = pd.read_csv(TRAIN_DIR / "train_labels.csv", encoding="utf-8-sig")
sample_submission = pd.read_csv(DATA_DIR / "sample_submission.csv", encoding="utf-8-sig")

ldaps_train = pd.read_csv(TRAIN_DIR / "ldaps_train.csv", encoding="utf-8-sig")
gfs_train = pd.read_csv(TRAIN_DIR / "gfs_train.csv", encoding="utf-8-sig")
ldaps_test = pd.read_csv(TEST_DIR / "ldaps_test.csv", encoding="utf-8-sig")
gfs_test = pd.read_csv(TEST_DIR / "gfs_test.csv", encoding="utf-8-sig")

train_labels["kst_dtm"] = pd.to_datetime(train_labels["kst_dtm"])
sample_submission["forecast_kst_dtm"] = pd.to_datetime(sample_submission["forecast_kst_dtm"])

scada_vestas = pd.read_csv(TRAIN_DIR / "scada_vestas_train.csv", encoding="utf-8-sig")
scada_unison = pd.read_csv(TRAIN_DIR / "scada_unison_train.csv", encoding="utf-8-sig")

print("train_labels:", train_labels.shape)
print("sample_submission:", sample_submission.shape)
print("ldaps_train:", ldaps_train.shape, "gfs_train:", gfs_train.shape)
print("ldaps_test:", ldaps_test.shape, "gfs_test:", gfs_test.shape)
# Out:
# train_labels: (26304, 4)
# sample_submission: (8760, 5)
# ldaps_train: (420864, 35) gfs_train: (236736, 40)
# ldaps_test: (140160, 35) gfs_test: (78840, 40)

# %% [markdown]
# ## 3. 데이터 전처리
# P1. SCADA 글리치 제거
#
# P2. Group 3 라벨 결측 처리
#
# P3. NWP U/V → 풍속/풍향 변환
#
# P4. Grid 선택
#
# P5. NWP 풍속 Bias Correction
#
# P6. Downtime 구간 플래깅
#
# P7. Temporal Feature Engineering
#
# P8. data_available_kst_dtm 활용 (leakage 방지)
#
# P9. 10% 제외 규칙을 학습에 반영
#
# P10. Train/Validation Split

# %%
# =====================================================================
# [런타임 무결성 완공] 3번 셀: 데이터 타입 동기화 및 누수 차단 버전
# =====================================================================
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# 1. 🎯 [에러 원인 저격] 원본 데이터프레임 본체의 컬럼 타입을 확실하게 datetime으로 변환
train_labels['kst_dtm'] = pd.to_datetime(train_labels['kst_dtm'])
scada_vestas['kst_dtm'] = pd.to_datetime(scada_vestas['kst_dtm'])
scada_unison['kst_dtm'] = pd.to_datetime(scada_unison['kst_dtm'])

ldaps_train['forecast_kst_dtm'] = pd.to_datetime(ldaps_train['forecast_kst_dtm'])
ldaps_train['data_available_kst_dtm'] = pd.to_datetime(ldaps_train['data_available_kst_dtm'])

gfs_train['forecast_kst_dtm'] = pd.to_datetime(gfs_train['forecast_kst_dtm'])
gfs_train['data_available_kst_dtm'] = pd.to_datetime(gfs_train['data_available_kst_dtm'])

ldaps_test['forecast_kst_dtm'] = pd.to_datetime(ldaps_test['forecast_kst_dtm'])
ldaps_test['data_available_kst_dtm'] = pd.to_datetime(ldaps_test['data_available_kst_dtm'])

gfs_test['forecast_kst_dtm'] = pd.to_datetime(gfs_test['forecast_kst_dtm'])
gfs_test['data_available_kst_dtm'] = pd.to_datetime(gfs_test['data_available_kst_dtm'])


# 2. NWP 가용성 필터링 (누수 방지)
def clean_nwp(df):
    df = df[df['data_available_kst_dtm'] <= df['forecast_kst_dtm']]
    df = df.sort_values(by=['forecast_kst_dtm', 'data_available_kst_dtm'])
    df = df.drop_duplicates(subset=['forecast_kst_dtm', 'grid_id'], keep='last')
    return df

print("Cleaning NWP data...")
ldaps_train = clean_nwp(ldaps_train)
gfs_train = clean_nwp(gfs_train)

# 🎯 Bias Map 산출 시 검증셋(2024년) 철저 배제, 오직 Train(2022~2023)만 활용
print("Building Spatial Forecast Wind Bias Map from Train SCADA (2022-2023 Only)...")
v_ws_cols = [c for c in scada_vestas.columns if '_ws' in c and 'ratio' not in c and 'mean' not in c]
scada_vestas['turbine_ws_mean_calc'] = scada_vestas[v_ws_cols].mean(axis=1)
v_hourly_ws = scada_vestas.groupby(scada_vestas['kst_dtm'].dt.floor('h'))['turbine_ws_mean_calc'].mean().reset_index()
v_hourly_ws.columns = ['kst_dtm', 'scada_real_ws']

# 오직 2022, 2023년 데이터만 타겟팅
train_timeline = train_labels[train_labels['kst_dtm'].dt.year.isin([2022, 2023])][['kst_dtm']].copy()
train_timeline['month'] = train_timeline['kst_dtm'].dt.month
train_timeline['hour'] = train_timeline['kst_dtm'].dt.hour

ldaps_temp = ldaps_train[ldaps_train['grid_id'] == 5].copy()
ldaps_temp['ws'] = np.sqrt(ldaps_temp['heightAboveGround_10_10u']**2 + ldaps_temp['heightAboveGround_10_10v']**2)
ldaps_temp_grouped = ldaps_temp.rename(columns={'forecast_kst_dtm': 'kst_dtm', 'ws': 'ldaps_ws'})[['kst_dtm', 'ldaps_ws']]

gfs_temp = gfs_train[gfs_train['grid_id'] == 5].copy()
gfs_temp['ws'] = np.sqrt(gfs_temp['heightAboveGround_10_10u']**2 + gfs_temp['heightAboveGround_10_10v']**2)
gfs_temp_grouped = gfs_temp.rename(columns={'forecast_kst_dtm': 'kst_dtm', 'ws': 'gfs_ws'})[['kst_dtm', 'gfs_ws']]

bias_base = pd.merge(train_timeline, ldaps_temp_grouped, on='kst_dtm', how='left')
bias_base = pd.merge(bias_base, gfs_temp_grouped, on='kst_dtm', how='left')
bias_base = pd.merge(bias_base, v_hourly_ws, on='kst_dtm', how='left')

bias_base['ldaps_bias_raw'] = bias_base['ldaps_ws'] - bias_base['scada_real_ws']
bias_base['gfs_bias_raw'] = bias_base['gfs_ws'] - bias_base['scada_real_ws']

historical_bias_map = bias_base.groupby(['month', 'hour'])[['ldaps_bias_raw', 'gfs_bias_raw']].mean().reset_index()
historical_bias_map.columns = ['month', 'hour', 'ldaps_historical_bias', 'gfs_historical_bias']

def process_nwp_features(df, prefix='ldaps'):
    # 1. 시계열 및 기본 인덱스 보존
    df_idx = df[['forecast_kst_dtm', 'grid_id', 'data_available_kst_dtm']].copy()
    df_idx['forecast_horizon_h'] = (df_idx['forecast_kst_dtm'] - df_idx['data_available_kst_dtm']).dt.total_seconds() / 3600.0
    
    # 2. 모델별 핵심 변수 맵핑 (기존 구조 완전 복구)
    if prefix == 'ldaps':
        u_col, v_col, t_col, p_col, h_col = 'heightAboveGround_10_10u', 'heightAboveGround_10_10v', 'heightAboveGround_2_t', 'surface_0_sp', 'heightAboveGround_2_r'
        extra_wind_cols, extra_env_cols = [], ['etc_0_blh', 'surface_0_ncpcp', 'surface_0_snol']
    else:  
        u_col, v_col, t_col, p_col, h_col = 'heightAboveGround_10_10u', 'heightAboveGround_10_10v', 'heightAboveGround_2_2t', 'surface_0_sp', 'heightAboveGround_2_2r'
        extra_wind_cols = ['heightAboveGround_80_u', 'heightAboveGround_80_v', 'heightAboveGround_100_100u', 'heightAboveGround_100_100v']
        extra_env_cols = ['surface_0_dswrf', 'surface_0_dlwrf', 'planetaryBoundaryLayer_0_VRATE']
        
    # 복사 에너지 및 돌풍 컬럼 유동적 추출 레이어 보존
    rad_cols = [col for col in df.columns if any(r in col for r in ['dswrf', 'NDNSW', 'SWDIR', 'SWDIF']) if col not in extra_env_cols]
    gust_cols = [c for c in df.columns if 'gust' in c.lower()]
    gust_col = gust_cols[0] if gust_cols else None
    
    # 타깃 서브셋 조립
    target_base_cols = [u_col, v_col, t_col, p_col, h_col] + rad_cols + extra_wind_cols + extra_env_cols
    if gust_col: target_base_cols.append(gust_col)
        
    df_sub = df[target_base_cols].copy()
    
    # 3. 수치물리 파생 변수 연산
    temp_c = df_sub[t_col] - 273.15  
    temp_k = df_sub[t_col]
    
    # [BUG FIX ①] 대기밀도 공식 무결성 확보 (Pa 단위 유지하여 100배 왜곡 현상 제거)
    e_s = 6.1078 * 10 ** ((7.5 * temp_c) / (temp_c + 237.3))
    e = (df_sub[h_col] / 100.0) * e_s * 100.0  # hPa를 Pa로 보정
    p_dry = df_sub[p_col] - e
    df_sub['air_density'] = (p_dry / (287.058 * temp_k)) + (e / (461.495 * temp_k))
    
    # 지상 10m 풍속/풍향 물리 변수 생성 (기존 비선형 차수 복구)
    bias_factor = 0.95 if prefix == 'ldaps' else 1.02
    df_sub['ws'] = np.sqrt(df_sub[u_col]**2 + df_sub[v_col]**2) * bias_factor
    df_sub['ws_squared'] = df_sub['ws'] ** 2
    df_sub['ws_cubed'] = df_sub['ws'] ** 3
    df_sub['wd'] = np.arctan2(-df_sub[u_col], -df_sub[v_col])
    df_sub['ws_sin'] = df_sub['ws'] * np.sin(df_sub['wd'])
    df_sub['ws_cos'] = df_sub['ws'] * np.cos(df_sub['wd'])
    df_sub['surface_0_sp_clean'] = df_sub[p_col]
    
    # GFS 고고도 풍속 물리 변수 생성 및 차수 확장
    if prefix == 'gfs':
        df_sub['ws_80m'] = np.sqrt(df_sub['heightAboveGround_80_u']**2 + df_sub['heightAboveGround_80_v']**2)
        df_sub['ws_80m_cubed'] = df_sub['ws_80m'] ** 3
        df_sub['ws_100m'] = np.sqrt(df_sub['heightAboveGround_100_100u']**2 + df_sub['heightAboveGround_100_100v']**2)
        df_sub['ws_100m_cubed'] = df_sub['ws_100m'] ** 3

    # 인덱스 재매핑
    df_sub['forecast_kst_dtm'] = df_idx['forecast_kst_dtm']
    df_sub['grid_id'] = df_idx['grid_id']
    
    # 4. 딕셔너리 집계 레이어 (유실되었던 기존 변수들과 복사 에너지 통째로 복구)
    agg_dict = {
        'ws': ['mean', 'max', 'std'], 
        'ws_squared': ['mean'], 
        'ws_cubed': ['mean', 'max'],
        'ws_sin': ['mean'], 
        'ws_cos': ['mean'], 
        'air_density': ['mean'], 
        'surface_0_sp_clean': ['mean']
    }
    
    # 모델별 특화 동적 변수 및 복사(Radiation) 컬럼들을 agg_dict에 완전 수혈
    for r_col in rad_cols:
        agg_dict[r_col] = ['mean']
    if gust_col:
        agg_dict[gust_col] = ['mean', 'max']
        
    # [BUG FIX ②] GFS 핵심 고고도 변수들의 변동성(max, std) 지표 수혈 및 누락 방지
    if prefix == 'gfs':
        agg_dict['ws_80m'] = ['mean', 'max', 'std']
        agg_dict['ws_80m_cubed'] = ['mean']
        agg_dict['ws_100m'] = ['mean', 'max', 'std']
        agg_dict['ws_100m_cubed'] = ['mean']
        agg_dict['planetaryBoundaryLayer_0_VRATE'] = ['mean']
    else:  
        agg_dict['etc_0_blh'] = ['mean']
        agg_dict['surface_0_ncpcp'] = ['mean']
        agg_dict['surface_0_snol'] = ['mean']
    
    # 최종 공간 격자 Groupby 축약
    grouped = df_sub.groupby(['forecast_kst_dtm', 'grid_id']).agg(agg_dict)
    grouped.columns = [f"{prefix}_{c[0]}_{c[1]}" for c in grouped.columns]
    return grouped.reset_index()

# 4. Temporal Feature 함수
def add_temporal_features(df, time_col):
    df['hour'] = df[time_col].dt.hour
    df['month'] = df[time_col].dt.month
    df['day_of_year'] = df[time_col].dt.dayofyear
    df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24.0)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24.0)
    return df

print("Extracting Spatial NWP features...")
ldaps_features_all = process_nwp_features(ldaps_train, prefix='ldaps')
gfs_features_all = process_nwp_features(gfs_train, prefix='gfs')

# 5. 프레임 조립 및 공간 기울기 구축
print("Merging Parallel Multi-Grid Spatial Channels...")
final_df = train_labels[['kst_dtm']].copy()
final_df = add_temporal_features(final_df, 'kst_dtm')
final_df = pd.merge(final_df, historical_bias_map, on=['month', 'hour'], how='left')

ldaps_target_grids, gfs_target_grids = [5, 6, 12], [5]
for gid in ldaps_target_grids:
    grid_sub = ldaps_features_all[ldaps_features_all['grid_id'] == gid].copy().drop(columns='grid_id')
    grid_sub.columns = [f"{col}_g{gid}" if col != 'forecast_kst_dtm' else col for col in grid_sub.columns]
    final_df = pd.merge(final_df, grid_sub, left_on='kst_dtm', right_on='forecast_kst_dtm', how='left').drop(columns='forecast_kst_dtm')

for gid in gfs_target_grids:
    grid_sub = gfs_features_all[gfs_features_all['grid_id'] == gid].copy().drop(columns='grid_id')
    grid_sub.columns = [f"{col}_g{gid}" if col != 'forecast_kst_dtm' else col for col in grid_sub.columns]
    final_df = pd.merge(final_df, grid_sub, left_on='kst_dtm', right_on='forecast_kst_dtm', how='left').drop(columns='forecast_kst_dtm')

# 공간 기울기 연산
final_df['spatial_grad_ws_5_6'] = final_df['ldaps_ws_mean_g6'] - final_df['ldaps_ws_mean_g5']
final_df['spatial_grad_ws_5_12'] = final_df['ldaps_ws_mean_g12'] - final_df['ldaps_ws_mean_g5']
final_df['spatial_grad_sp_5_6'] = final_df['ldaps_surface_0_sp_clean_mean_g6'] - final_df['ldaps_surface_0_sp_clean_mean_g5']
final_df['spatial_grad_sp_5_12'] = final_df['ldaps_surface_0_sp_clean_mean_g12'] - final_df['ldaps_surface_0_sp_clean_mean_g5']

final_df['ldaps_ws_mean'] = final_df['ldaps_ws_mean_g5']
final_df['gfs_ws_mean'] = final_df['gfs_ws_mean_g5']

final_df = pd.merge(final_df, train_labels, on='kst_dtm', how='inner')
final_df = final_df.sort_values('kst_dtm').reset_index(drop=True)

# 시계열 인접 변수 연산
for prefix in ['ldaps', 'gfs']:
    final_df[f'{prefix}_ws_mean_lag1'] = final_df[f'{prefix}_ws_mean'].shift(1)
    final_df[f'{prefix}_ws_mean_lead1'] = final_df[f'{prefix}_ws_mean'].shift(-1)
    final_df[f'{prefix}_ws_rolling_3h'] = final_df[f'{prefix}_ws_mean'].rolling(window=3, min_periods=1).mean()

time_lag_cols = [f'{p}_ws_mean_lag1' for p in ['ldaps', 'gfs']] + [f'{p}_ws_mean_lead1' for p in ['ldaps', 'gfs']] + [f'{p}_ws_rolling_3h' for p in ['ldaps', 'gfs'] ]
final_df[time_lag_cols] = final_df[time_lag_cols].bfill().ffill()

# 6. Group 3 라벨 결측 대치 (기존 선형회귀 대치 보존)
valid_g3 = final_df[final_df['kpx_group_3'].notnull() & final_df['kpx_group_1'].notnull() & final_df['kpx_group_2'].notnull()]
missing_g3 = final_df[final_df['kpx_group_3'].isnull() & final_df['kpx_group_1'].notnull() & final_df['kpx_group_2'].notnull()]
if len(missing_g3) > 0:
    print("Imputing Group 3 missing labels...")
    lr = LinearRegression()
    lr.fit(valid_g3[['kpx_group_1', 'kpx_group_2']], valid_g3['kpx_group_3'])
    final_df.loc[missing_g3.index, 'kpx_group_3'] = lr.predict(missing_g3[['kpx_group_1', 'kpx_group_2']])

print("🥇 [공간 기울기 결합 완전체] 기단 공사 마침표 완공!")
# Out:
# Cleaning NWP data...
# Building Spatial Forecast Wind Bias Map from Train SCADA (2022-2023 Only)...
# Extracting Spatial NWP features...
# Merging Parallel Multi-Grid Spatial Channels...
# Imputing Group 3 missing labels...
# 🥇 [공간 기울기 결합 완전체] 기단 공사 마침표 완공!

# %% [markdown]
# ## 4. Feature 생성
#
# LDAPS/GFS는 하나의 예측 시각에 여러 격자가 존재하므로, `forecast_kst_dtm`별로 수치형 기상변수의 평균값을 계산합니다.
#
# 추가로 월, 일, 시간, 요일, 주말 여부, 시간/월의 주기성을 나타내는 sin-cos feature를 생성합니다.

# %%
# =====================================================================
# [문법 무결성 완공] 4번 셀: 백슬래시 에러 제거 및 피처 격리 버전
# =====================================================================
print("Cleaning TEST NWP data...")
ldaps_test_clean = clean_nwp(ldaps_test)
gfs_test_clean = clean_nwp(gfs_test)

print("Extracting TEST NWP features...")
ldaps_test_features_all = process_nwp_features(ldaps_test_clean, prefix='ldaps')
gfs_test_features_all = process_nwp_features(gfs_test_clean, prefix='gfs')

print("Assembling test_df based purely on sample_submission order...")
# 원본 양식의 순서(forecast_id)를 절대 깨지 않기 위해 정렬 생략 및 순서 고정
test_df = sample_submission[["forecast_id", "forecast_kst_dtm"]].copy()
test_df = add_temporal_features(test_df, 'forecast_kst_dtm')
test_df = pd.merge(test_df, historical_bias_map, on=['month', 'hour'], how='left')

for gid in ldaps_target_grids:
    grid_sub = ldaps_test_features_all[ldaps_test_features_all['grid_id'] == gid].copy().drop(columns='grid_id')
    # 🎯 [핵심 보정] 문법 에러의 주범이었던 백슬래시(\)를 제거하고 깔끔한 f-string으로 전면 수정
    grid_sub.columns = [f"{col}_g{gid}" if col != 'forecast_kst_dtm' else col for col in grid_sub.columns]
    test_df = pd.merge(test_df, grid_sub, on='forecast_kst_dtm', how='left')

for gid in gfs_target_grids:
    grid_sub = gfs_test_features_all[gfs_test_features_all['grid_id'] == gid].copy().drop(columns='grid_id')
    # 🎯 [핵심 보정] 문법 에러의 주범이었던 백슬래시(\)를 제거하고 깔끔한 f-string으로 전면 수정
    grid_sub.columns = [f"{col}_g{gid}" if col != 'forecast_kst_dtm' else col for col in grid_sub.columns]
    test_df = pd.merge(test_df, grid_sub, on='forecast_kst_dtm', how='left')

# 테스트셋 공간 기울기 결합
test_df['spatial_grad_ws_5_6'] = test_df['ldaps_ws_mean_g6'] - test_df['ldaps_ws_mean_g5']
test_df['spatial_grad_ws_5_12'] = test_df['ldaps_ws_mean_g12'] - test_df['ldaps_ws_mean_g5']
test_df['spatial_grad_sp_5_6'] = test_df['ldaps_surface_0_sp_clean_mean_g6'] - test_df['ldaps_surface_0_sp_clean_mean_g5']
test_df['spatial_grad_sp_5_12'] = test_df['ldaps_surface_0_sp_clean_mean_g12'] - test_df['ldaps_surface_0_sp_clean_mean_g5']

test_df['ldaps_ws_mean'] = test_df['ldaps_ws_mean_g5']
test_df['gfs_ws_mean'] = test_df['gfs_ws_mean_g5']

# 시계열 변수 채우기
for prefix in ['ldaps', 'gfs']:
    test_df[f'{prefix}_ws_mean_lag1'] = test_df[f'{prefix}_ws_mean'].shift(1)
    test_df[f'{prefix}_ws_mean_lead1'] = test_df[f'{prefix}_ws_mean'].shift(-1)
    test_df[f'{prefix}_ws_rolling_3h'] = test_df[f'{prefix}_ws_mean'].rolling(window=3, min_periods=1).mean()
test_df[time_lag_cols] = test_df[time_lag_cols].bfill().ffill()

print("Splitting datasets...")
train_set = final_df[final_df['kst_dtm'].dt.year.isin([2022, 2023])].copy()
valid_set = final_df[final_df['kst_dtm'].dt.year == 2024].copy()

# 다운타임 및 정답 누수 관련 피처 차단 목록
drop_features = [
    'kst_dtm', 'forecast_kst_dtm', 'data_available_kst_dtm', 'grid_id', 
    'ldaps_ws_mean', 'gfs_ws_mean', 'forecast_id',
    'vestas_downtime_ratio', 'unison_downtime_ratio', 
    'total_downtime_count', 'active_turbine_count', 'scada_downtime_ratio_10m'
]

X_train = train_set.drop(columns=TARGET_COLS + [col for col in drop_features if col in train_set.columns], errors='ignore')
y_train = train_set[TARGET_COLS]

X_val = valid_set.drop(columns=TARGET_COLS + [col for col in drop_features if col in valid_set.columns], errors='ignore')
y_val = valid_set[TARGET_COLS]

X_test = test_df.drop(columns=[col for col in drop_features if col in test_df.columns], errors='ignore')
X_test = X_test.reindex(columns=X_train.columns)

print("\n--- 파이프라인 최종 조립 완료 ---")
print("X_train (학습 피처) 셰이프:", X_train.shape)
print("X_val   (검증 피처) 셰이프:", X_val.shape)
print("X_test  (평가 피처) 셰이프:", X_test.shape)
# Out:
# Cleaning TEST NWP data...
# Extracting TEST NWP features...
# Assembling test_df based purely on sample_submission order...
# Splitting datasets...
#
# --- 파이프라인 최종 조립 완료 ---
# X_train (학습 피처) 셰이프: (17519, 86)
# X_val   (검증 피처) 셰이프: (8784, 86)
# X_test  (평가 피처) 셰이프: (8760, 86)

# %%
# # === 4.5번 셀: 변수명 완벽 격리 + 시드 고정 버전 ===
# import optuna
# from optuna.samplers import TPESampler
# import lightgbm as lgb
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.impute import SimpleImputer

# print("🔥 [ALL TARGETS] 대회 산식(FICR) 최대화 변수 격리 튜닝 시작...")

# imputer = SimpleImputer(strategy="median")
# X_train_numeric = X_train.select_dtypes(include=[np.number])
# X_train_imp_local = pd.DataFrame(imputer.fit_transform(X_train_numeric), columns=X_train_numeric.columns)

# best_params_dict = {}

# def calculate_custom_ficr(y_true, y_pred, capacity):
#     eval_mask = y_true >= (capacity * 0.1)
#     if eval_mask.sum() == 0:
#         return 0
#     y_true_eval = y_true[eval_mask]
#     y_pred_eval = y_pred[eval_mask]
    
#     absolute_errors = np.abs(y_pred_eval - y_true_eval)
#     hourly_nmae = absolute_errors / capacity
    
#     revenue = np.where(hourly_nmae <= 0.06, 4.0, 
#                        np.where(hourly_nmae <= 0.08, 3.0, 0.0))
#     max_revenue = len(y_true_eval) * 4.0
#     return revenue.sum() / max_revenue

# for target_col in TARGET_COLS:
#     print(f"\n🎯 [{target_col}] 파라미터 사냥 중...")
    
#     train_mask = train_set[target_col].notna()
#     X_opt = X_train_imp_local.loc[train_mask]
#     y_opt = train_set.loc[train_mask, target_col].values
    
#     # 🎯 [핵심] X_val 변수명이 오염되지 않도록 뒤에 _opt를 붙여 철저히 분리합니다.
#     X_tr_opt, X_val_opt, y_tr_opt, y_val_opt = train_test_split(X_opt, y_opt, test_size=0.2, random_state=42)
#     target_capacity = CAPACITY_KWH[target_col]
    
#     def objective(trial):
#         params = {
#             'n_estimators': trial.suggest_int('n_estimators', 400, 1200, step=50),
#             'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.06, log=True),
#             'max_depth': trial.suggest_int('max_depth', 6, 12),
#             'num_leaves': trial.suggest_int('num_leaves', 31, 127),
#             'min_child_samples': trial.suggest_int('min_child_samples', 15, 35),
#             'subsample': trial.suggest_float('subsample', 0.65, 0.95),
#             'colsample_bytree': trial.suggest_float('colsample_bytree', 0.65, 0.95),
#             'random_state': 42,
#             'n_jobs': -1,
#             'verbose': -1
#         }
        
#         model = lgb.LGBMRegressor(**params)
#         model.fit(X_tr_opt, y_tr_opt)
        
#         preds = model.predict(X_val_opt)
#         preds = np.clip(preds, 0, target_capacity)
        
#         ficr_score = calculate_custom_ficr(y_val_opt, preds, target_capacity)
#         return 1.0 - ficr_score

#     fixed_sampler = TPESampler(seed=42)
#     study = optuna.create_study(direction='minimize', sampler=fixed_sampler)
#     study.optimize(objective, n_trials=20)
    
#     best_params_dict[target_col] = study.best_trial.params
#     print(f"▶ [{target_col}] 최고 가상 FICR: {1.0 - study.best_value:.5f}")

# print("\n🏆 모든 타겟 격리 사냥 완료!")

# %%
# # 🎯 [완벽 보정] 진짜 부활한 기상 변수들이 들어있는지 정확하게 저격 검증
# check_cols = [col for col in X_train.columns if any(w in col for w in ['ws', 'density', 'humidity', 'pressure'])]

# if len(check_cols) > 0:
#     print("✅ 성공: 부활한 기온/기압/대기밀도 변수들이 모델 입력(X_train)에 100% 포함되어 있습니다!")
#     print(f"▶ X_train의 최종 피처 개수: {X_train.shape[1]}개")
#     print(f"▶ 포함된 소중한 기상 피처들: {check_cols[:5]}")
# else:
#     print("❌ 경고: 기상 데이터가 정상적으로 수혈되지 않았습니다.")

# %% [markdown]
# ## 5. 모델 학습
#
# KPX 그룹별로 Label 제공 기간이 다르므로, 각 그룹의 Label이 존재하는 행만 사용해 RandomForest 모델을 따로 학습합니다.
#
# RandomForest는 여러 결정트리를 앙상블하는 배깅(Bagging) 모델로, 각 트리를 부트스트랩 샘플과 랜덤 피처
# subset으로 학습한 뒤 예측을 평균 냅니다.

# %%
# =====================================================================
# [런타임 무결성 완공] 5번 셀: 3대 모델 체급 업그레이드 & 실시간 모니터링 버전
# =====================================================================
import lightgbm as lgb
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.model_selection import KFold
from sklearn.impute import SimpleImputer
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

print("⏳ 1. 수치형 피처 추출 및 SimpleImputer 정밀 동기화 중...")

# 수치형 데이터 슬라이싱 및 컬럼 순서 강제 일치 (기존 구조 100% 보존)
X_train_numeric = X_train.select_dtypes(include=[np.number])
X_val_numeric = X_val.select_dtypes(include=[np.number])
X_test_numeric = X_test.select_dtypes(include=[np.number])

X_val_numeric = X_val_numeric.reindex(columns=X_train_numeric.columns)
X_test_numeric = X_test_numeric.reindex(columns=X_train_numeric.columns)

imputer = SimpleImputer(strategy="median")
X_train_trans = imputer.fit_transform(X_train_numeric)
X_val_trans = imputer.transform(X_val_numeric)
X_test_trans = imputer.transform(X_test_numeric)

passed_features = imputer.get_feature_names_out(X_train_numeric.columns)

X_train_imp = pd.DataFrame(X_train_trans, columns=passed_features, index=train_set.index)
X_val_imp = pd.DataFrame(X_val_trans, columns=passed_features, index=valid_set.index)
X_test_imp = pd.DataFrame(X_test_trans, columns=passed_features, index=sample_submission.index)

print(f"✅ 피처 매트릭스 빌드 완료! (최종 피처 개수: {X_train_imp.shape[1]}개)")

# 데이터프레임 초기화 레이어 (후속 셀 호환성 100% 확보)
valid_preds_lgb = pd.DataFrame(0.0, index=valid_set.index, columns=TARGET_COLS)
valid_preds_xgb = pd.DataFrame(0.0, index=valid_set.index, columns=TARGET_COLS)
valid_preds_cat = pd.DataFrame(0.0, index=valid_set.index, columns=TARGET_COLS)

final_preds_lgb = pd.DataFrame(0.0, index=sample_submission.index, columns=TARGET_COLS)
final_preds_xgb = pd.DataFrame(0.0, index=sample_submission.index, columns=TARGET_COLS)
final_preds_cat = pd.DataFrame(0.0, index=sample_submission.index, columns=TARGET_COLS)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

print("\n⚡ [Modeling Stage] 실시간 스코어 모니터링 교차 검증 시작...\n")

for target in TARGET_COLS:
    print(f"\n==================== 🎯 TARGET: {target} 훈련 시작 ====================")
    
    train_mask = train_set[target].notna()
    X_target = X_train_imp.loc[train_mask].reset_index(drop=True)
    y_target = train_set.loc[train_mask, target].reset_index(drop=True).astype(float).values
    
    target_capacity = CAPACITY_KWH[target]
    threshold = target_capacity * 0.10
    
    t_preds_lgb = np.zeros(len(X_test_imp))
    t_preds_xgb = np.zeros(len(X_test_imp))
    t_preds_cat = np.zeros(len(X_test_imp))
    
    v_preds_lgb = np.zeros(len(X_val_imp))
    v_preds_xgb = np.zeros(len(X_val_imp))
    v_preds_cat = np.zeros(len(X_val_imp))
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(X_target, y_target)):
        print(f"\n▶ 📂 [Fold {fold+1}/5] 내부 분할 학습 진행 중...")
        X_tr, X_va = X_target.iloc[train_idx], X_target.iloc[val_idx]
        y_tr, y_va = y_target[train_idx], y_target[val_idx]
        
        sample_weights = np.where(y_tr < threshold, 0.01, 1.0)
        
        model_lgb = lgb.LGBMRegressor(
            objective='regression_l1',
            n_estimators=1500,          # 2000 -> 1500으로 약간 축소
            learning_rate=0.015,        # 보폭을 다시 기존의 기민한 수준으로 복구
            max_depth=8,                # 깊이를 너무 깊지 않게 방어 (10 -> 8)
            num_leaves=63,              # 트리 복잡도 완화 (127 -> 63)
            min_child_samples=30, subsample=0.8, colsample_bytree=0.6, 
            random_state=42, n_jobs=-1, verbose=-1
        )
        
        model_lgb.fit(
            X_tr, y_tr, sample_weight=sample_weights,
            eval_set=[(X_va, y_va)],
            callbacks=[lgb.early_stopping(stopping_rounds=70, verbose=False), # early stopping 라운드 여유 최적화
                       lgb.log_evaluation(period=200)] # 200 주기 로그 출력
        )
        v_preds_lgb += np.clip(model_lgb.predict(X_val_imp), 0, target_capacity) / kf.n_splits
        t_preds_lgb += np.clip(model_lgb.predict(X_test_imp), 0, target_capacity) / kf.n_splits
        
        # 2) XGBoost 조정
        model_xgb = XGBRegressor(
            objective='reg:absoluteerror', eval_metric='mae',
            n_estimators=1500,          # 2000 -> 1500으로 조정
            learning_rate=0.015,
            max_depth=7,                # 과적합 방지를 위해 깊이 완화 (9 -> 7)
            subsample=0.8, colsample_bytree=0.6, tree_method='hist',
            random_state=42, n_jobs=-1, early_stopping_rounds=50
        )
        model_xgb.fit(
            X_tr, y_tr, sample_weight=sample_weights,
            eval_set=[(X_va, y_va)], verbose=200
        )
        v_preds_xgb += np.clip(model_xgb.predict(X_val_imp), 0, target_capacity) / kf.n_splits
        t_preds_xgb += np.clip(model_xgb.predict(X_test_imp), 0, target_capacity) / kf.n_splits
        
        # 3) CatBoost 조정 (우리의 성능 대장이므로 정밀도 유지)
        model_cat = CatBoostRegressor(
            loss_function='MAE', eval_metric='MAE',
            iterations=2000,            # 2500 -> 2000으로 미세 조정하여 과적합 방지
            learning_rate=0.015,
            depth=6,                    # 구조적 복잡도 완화 (7 -> 6)
            bootstrap_type='Bernoulli', subsample=0.8,
            random_seed=42, early_stopping_rounds=50
        )
        model_cat.fit(
            X_tr, y_tr, sample_weight=sample_weights,
            eval_set=[(X_va, y_va)], verbose=300 # 300 주기 로그 출력
        )
        v_preds_cat += np.clip(model_cat.predict(X_val_imp), 0, target_capacity) / kf.n_splits
        t_preds_cat += np.clip(model_cat.predict(X_test_imp), 0, target_capacity) / kf.n_splits
        
    valid_preds_lgb[target] = v_preds_lgb
    valid_preds_xgb[target] = v_preds_xgb
    valid_preds_cat[target] = v_preds_cat
    
    final_preds_lgb[target] = t_preds_lgb
    final_preds_xgb[target] = t_preds_xgb
    final_preds_cat[target] = t_preds_cat

print("\n🏆 [성공] 변수 누락 지뢰가 완전히 박멸되었습니다! 이어서 최적화 블렌딩 셀(7번)을 구동해 주세요.")
# Out:
# ⏳ 1. 수치형 피처 추출 및 SimpleImputer 정밀 동기화 중...
# ✅ 피처 매트릭스 빌드 완료! (최종 피처 개수: 80개)
#
# ⚡ [Modeling Stage] 실시간 스코어 모니터링 교차 검증 시작...
#
#
# ==================== 🎯 TARGET: kpx_group_1 훈련 시작 ====================
#
# ▶ 📂 [Fold 1/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2899.14
# [400]	valid_0's l1: 2685.1
# [600]	valid_0's l1: 2593.51
# [800]	valid_0's l1: 2535.62
# [1000]	valid_0's l1: 2493.16
# [1200]	valid_0's l1: 2467.63
# [1400]	valid_0's l1: 2449.14
# [0]	validation_0-mae:6632.15752
# [200]	validation_0-mae:2922.60551
# [400]	validation_0-mae:2709.63584
# [600]	validation_0-mae:2645.09493
# [800]	validation_0-mae:2612.39498
# [1000]	validation_0-mae:2592.64972
# [1200]	validation_0-mae:2578.04740
# [1400]	validation_0-mae:2568.90440
# [1499]	validation_0-mae:2558.50354
# 0:	learn: 4794.6185050	test: 6611.9383328	best: 6611.9383328 (0)	total: 163ms	remaining: 5m 25s
# 300:	learn: 2984.7871319	test: 2260.3525047	best: 2260.3525047 (300)	total: 4.12s	remaining: 23.2s
# 600:	learn: 2896.7501376	test: 2201.0156572	best: 2201.0156572 (600)	total: 8s	remaining: 18.6s
# 900:	learn: 2792.8107223	test: 2163.2208600	best: 2163.2208600 (900)	total: 12.4s	remaining: 15.1s
# 1200:	learn: 2705.0592033	test: 2133.4514552	best: 2133.4514552 (1200)	total: 17.2s	remaining: 11.5s
# 1500:	learn: 2640.9591857	test: 2116.5666502	best: 2116.5666502 (1500)	total: 21.9s	remaining: 7.28s
# 1800:	learn: 2603.3382202	test: 2106.3706179	best: 2106.3436379 (1796)	total: 25.9s	remaining: 2.86s
# 1999:	learn: 2585.7644565	test: 2101.7285884	best: 2101.7285884 (1999)	total: 28.6s	remaining: 0us
#
# bestTest = 2101.728588
# bestIteration = 1999
#
#
# ▶ 📂 [Fold 2/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2887.5
# [400]	valid_0's l1: 2668.61
# [600]	valid_0's l1: 2598.73
# [800]	valid_0's l1: 2520.11
# [1000]	valid_0's l1: 2476.97
# [1200]	valid_0's l1: 2445.51
# [1400]	valid_0's l1: 2424.53
# [0]	validation_0-mae:6565.65696
# [200]	validation_0-mae:2918.16398
# [400]	validation_0-mae:2704.76249
# [600]	validation_0-mae:2646.00493
# [800]	validation_0-mae:2615.44013
# [858]	validation_0-mae:2617.74438
# 0:	learn: 4813.4456238	test: 6544.9498617	best: 6544.9498617 (0)	total: 15.2ms	remaining: 30.5s
# 300:	learn: 2978.3336046	test: 2270.9988118	best: 2270.9988118 (300)	total: 4.2s	remaining: 23.7s
# 600:	learn: 2889.9570540	test: 2212.6776445	best: 2212.6776445 (600)	total: 7.78s	remaining: 18.1s
# 900:	learn: 2790.0323054	test: 2174.8311902	best: 2174.8311902 (900)	total: 11.6s	remaining: 14.2s
# 1200:	learn: 2696.3785369	test: 2140.9142494	best: 2140.9142494 (1200)	total: 15.3s	remaining: 10.2s
# 1500:	learn: 2636.5138652	test: 2120.7451840	best: 2120.7208637 (1498)	total: 18.9s	remaining: 6.29s
# 1800:	learn: 2590.6749879	test: 2107.4891854	best: 2107.4891854 (1800)	total: 22.7s	remaining: 2.5s
# 1999:	learn: 2562.6844388	test: 2101.5959417	best: 2101.5959417 (1999)	total: 25.1s	remaining: 0us
#
# bestTest = 2101.595942
# bestIteration = 1999
#
#
# ▶ 📂 [Fold 3/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2967.73
# [400]	valid_0's l1: 2748.2
# [600]	valid_0's l1: 2667.25
# [800]	valid_0's l1: 2601.1
# [1000]	valid_0's l1: 2565.45
# [1200]	valid_0's l1: 2540.42
# [1400]	valid_0's l1: 2518.93
# [0]	validation_0-mae:6473.84609
# [200]	validation_0-mae:3006.28820
# [400]	validation_0-mae:2798.80213
# [600]	validation_0-mae:2733.58564
# [800]	validation_0-mae:2698.00736
# [1000]	validation_0-mae:2681.38537
# [1200]	validation_0-mae:2662.38739
# [1400]	validation_0-mae:2648.88216
# [1422]	validation_0-mae:2650.09114
# 0:	learn: 4804.1956057	test: 6454.1288509	best: 6454.1288509 (0)	total: 11.9ms	remaining: 23.8s
# 300:	learn: 2937.9928284	test: 2437.9429373	best: 2437.9429373 (300)	total: 3.91s	remaining: 22.1s
# 600:	learn: 2851.2045264	test: 2373.1674771	best: 2373.1674771 (600)	total: 7.61s	remaining: 17.7s
# 900:	learn: 2753.7666207	test: 2335.7699401	best: 2335.7612426 (899)	total: 11.5s	remaining: 14.1s
# 1200:	learn: 2673.5127200	test: 2308.6743299	best: 2308.6743299 (1200)	total: 15.3s	remaining: 10.2s
# 1500:	learn: 2615.2596615	test: 2290.6794881	best: 2290.6663065 (1499)	total: 18.8s	remaining: 6.24s
# 1800:	learn: 2566.4515545	test: 2274.7243640	best: 2274.7243640 (1800)	total: 22.1s	remaining: 2.44s
# 1999:	learn: 2539.8300019	test: 2266.9433040	best: 2266.9373423 (1997)	total: 24.3s	remaining: 0us
#
# bestTest = 2266.937342
# bestIteration = 1997
#
# Shrink model to first 1998 iterations.
#
# ▶ 📂 [Fold 4/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2924.3
# [400]	valid_0's l1: 2704.82
# [600]	valid_0's l1: 2618.9
# [800]	valid_0's l1: 2549.35
# [1000]	valid_0's l1: 2502.69
# [1200]	valid_0's l1: 2479.53
# [1400]	valid_0's l1: 2458.91
# [0]	validation_0-mae:6572.55551
# [200]	validation_0-mae:2951.45238
# [400]	validation_0-mae:2736.54709
# [600]	validation_0-mae:2672.83171
# [800]	validation_0-mae:2639.67499
# [1000]	validation_0-mae:2622.74394
# [1200]	validation_0-mae:2608.57667
# [1400]	validation_0-mae:2600.30310
# [1499]	validation_0-mae:2595.80786
# 0:	learn: 4830.7785833	test: 6551.0136739	best: 6551.0136739 (0)	total: 12.4ms	remaining: 24.7s
# 300:	learn: 2976.3958385	test: 2274.7726983	best: 2274.7726983 (300)	total: 3.48s	remaining: 19.6s
# 600:	learn: 2868.5735152	test: 2204.0307824	best: 2204.0307824 (600)	total: 6.78s	remaining: 15.8s
# 900:	learn: 2768.2579200	test: 2164.6306182	best: 2164.6306182 (900)	total: 10.1s	remaining: 12.3s
# 1200:	learn: 2701.0159058	test: 2144.1638170	best: 2144.1511241 (1199)	total: 13.5s	remaining: 8.95s
# 1500:	learn: 2646.4388272	test: 2127.9594176	best: 2127.9070404 (1498)	total: 16.8s	remaining: 5.59s
# 1800:	learn: 2607.9709822	test: 2118.8204037	best: 2118.8204037 (1800)	total: 20.1s	remaining: 2.22s
# 1999:	learn: 2580.4102507	test: 2112.4120039	best: 2112.4120039 (1999)	total: 22.4s	remaining: 0us
#
# bestTest = 2112.412004
# bestIteration = 1999
#
#
# ▶ 📂 [Fold 5/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2877.02
# [400]	valid_0's l1: 2669.32
# [600]	valid_0's l1: 2574.16
# [800]	valid_0's l1: 2506.1
# [1000]	valid_0's l1: 2474.51
# [1200]	valid_0's l1: 2447.04
# [1400]	valid_0's l1: 2423.22
# [0]	validation_0-mae:6625.94093
# [200]	validation_0-mae:2896.98541
# [400]	validation_0-mae:2690.93154
# [600]	validation_0-mae:2632.40120
# [800]	validation_0-mae:2598.98922
# [1000]	validation_0-mae:2579.00137
# [1200]	validation_0-mae:2562.29516
# [1324]	validation_0-mae:2561.94234
# 0:	learn: 4793.1032419	test: 6607.1790756	best: 6607.1790756 (0)	total: 11.3ms	remaining: 22.6s
# 300:	learn: 2980.0051918	test: 2249.1003070	best: 2249.1003070 (300)	total: 3.55s	remaining: 20s
# 600:	learn: 2884.7435705	test: 2189.7511113	best: 2189.7511113 (600)	total: 6.89s	remaining: 16s
# 900:	learn: 2769.4892871	test: 2150.0318077	best: 2150.0318077 (900)	total: 10.2s	remaining: 12.4s
# 1200:	learn: 2683.6983223	test: 2122.1421429	best: 2122.1421429 (1200)	total: 13.6s	remaining: 9.03s
# 1500:	learn: 2619.2471246	test: 2102.3603779	best: 2102.3536953 (1499)	total: 16.9s	remaining: 5.62s
# 1800:	learn: 2576.6324295	test: 2090.2122236	best: 2090.2116827 (1799)	total: 20.3s	remaining: 2.24s
# 1999:	learn: 2551.9748354	test: 2082.7016443	best: 2082.7016443 (1999)	total: 22.5s	remaining: 0us
#
# bestTest = 2082.701644
# bestIteration = 1999
#
#
# ==================== 🎯 TARGET: kpx_group_2 훈련 시작 ====================
#
# ▶ 📂 [Fold 1/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 3077.44
# [400]	valid_0's l1: 2787.98
# [600]	valid_0's l1: 2703.63
# [800]	valid_0's l1: 2658.98
# [1000]	valid_0's l1: 2618.95
# [1200]	valid_0's l1: 2590.17
# [1400]	valid_0's l1: 2555.19
# [0]	validation_0-mae:7261.78740
# [200]	validation_0-mae:3070.15018
# [400]	validation_0-mae:2821.84118
# [600]	validation_0-mae:2763.06810
# [800]	validation_0-mae:2731.54923
# [1000]	validation_0-mae:2712.31694
# [1200]	validation_0-mae:2699.75666
# [1400]	validation_0-mae:2686.44928
# [1488]	validation_0-mae:2687.83337
# 0:	learn: 5221.9996970	test: 7238.6214272	best: 7238.6214272 (0)	total: 11.6ms	remaining: 23.1s
# 300:	learn: 3034.0132815	test: 2424.0623345	best: 2424.0623345 (300)	total: 3.46s	remaining: 19.6s
# 600:	learn: 2921.1320524	test: 2348.3403891	best: 2348.3403891 (600)	total: 6.82s	remaining: 15.9s
# 900:	learn: 2814.3103449	test: 2300.4507832	best: 2300.4507832 (900)	total: 10.2s	remaining: 12.4s
# 1200:	learn: 2746.7083263	test: 2278.7439974	best: 2278.7439974 (1200)	total: 13.5s	remaining: 9s
# 1500:	learn: 2694.6410017	test: 2263.8182663	best: 2263.8182663 (1500)	total: 16.9s	remaining: 5.61s
# 1800:	learn: 2650.1081976	test: 2252.0127228	best: 2252.0127228 (1800)	total: 20.3s	remaining: 2.24s
# 1999:	learn: 2622.9583222	test: 2245.6381680	best: 2245.6381680 (1999)	total: 22.5s	remaining: 0us
#
# bestTest = 2245.638168
# bestIteration = 1999
#
#
# ▶ 📂 [Fold 2/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 3065.19
# [400]	valid_0's l1: 2793.83
# [600]	valid_0's l1: 2712.09
# [800]	valid_0's l1: 2661.53
# [1000]	valid_0's l1: 2629.7
# [1200]	valid_0's l1: 2602.23
# [1400]	valid_0's l1: 2573.52
# [0]	validation_0-mae:7348.19454
# [200]	validation_0-mae:3091.51976
# [400]	validation_0-mae:2847.84310
# [600]	validation_0-mae:2782.60307
# [800]	validation_0-mae:2757.26762
# [1000]	validation_0-mae:2738.27270
# [1200]	validation_0-mae:2725.48284
# [1285]	validation_0-mae:2725.84704
# 0:	learn: 5229.3313600	test: 7326.2380799	best: 7326.2380799 (0)	total: 14.1ms	remaining: 28.1s
# 300:	learn: 3022.0996908	test: 2357.6616613	best: 2357.6616613 (300)	total: 3.56s	remaining: 20.1s
# 600:	learn: 2915.7966827	test: 2288.5972502	best: 2288.5972502 (600)	total: 6.93s	remaining: 16.1s
# 900:	learn: 2820.5321185	test: 2256.7358992	best: 2256.7358992 (900)	total: 10.3s	remaining: 12.6s
# 1200:	learn: 2745.7725346	test: 2232.5068725	best: 2232.5068725 (1200)	total: 13.7s	remaining: 9.14s
# 1500:	learn: 2691.0516789	test: 2217.3472509	best: 2217.3169544 (1498)	total: 17.1s	remaining: 5.69s
# 1800:	learn: 2651.2104989	test: 2205.8825255	best: 2205.8825255 (1800)	total: 20.5s	remaining: 2.27s
# 1999:	learn: 2626.5053905	test: 2198.9176924	best: 2198.9084973 (1997)	total: 22.8s	remaining: 0us
#
# bestTest = 2198.908497
# bestIteration = 1997
#
# Shrink model to first 1998 iterations.
#
# ▶ 📂 [Fold 3/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 3088.23
# [400]	valid_0's l1: 2839.65
# [600]	valid_0's l1: 2764.1
# [800]	valid_0's l1: 2711.01
# [1000]	valid_0's l1: 2673.78
# [1200]	valid_0's l1: 2632.63
# [1400]	valid_0's l1: 2609.64
# [0]	validation_0-mae:7265.28554
# [200]	validation_0-mae:3105.98234
# [400]	validation_0-mae:2858.75006
# [600]	validation_0-mae:2797.95171
# [800]	validation_0-mae:2769.77200
# [1000]	validation_0-mae:2755.91357
# [1200]	validation_0-mae:2745.55821
# [1400]	validation_0-mae:2736.99234
# [1499]	validation_0-mae:2735.32822
# 0:	learn: 5226.0086025	test: 7242.6164242	best: 7242.6164242 (0)	total: 14.1ms	remaining: 28.3s
# 300:	learn: 3020.4077908	test: 2442.0751742	best: 2442.0751742 (300)	total: 3.75s	remaining: 21.1s
# 600:	learn: 2932.2845211	test: 2369.8983685	best: 2369.8983685 (600)	total: 7.13s	remaining: 16.6s
# 900:	learn: 2837.3419305	test: 2326.8146535	best: 2326.6928395 (897)	total: 10.5s	remaining: 12.9s
# 1200:	learn: 2756.9551826	test: 2299.9642758	best: 2299.9642758 (1200)	total: 13.9s	remaining: 9.26s
# 1500:	learn: 2699.6081877	test: 2282.0308147	best: 2282.0308147 (1500)	total: 17.3s	remaining: 5.76s
# 1800:	learn: 2655.7212432	test: 2269.6381366	best: 2269.5834257 (1798)	total: 20.8s	remaining: 2.29s
# 1999:	learn: 2630.2151885	test: 2262.7923420	best: 2262.7923420 (1999)	total: 23.1s	remaining: 0us
#
# bestTest = 2262.792342
# bestIteration = 1999
#
#
# ▶ 📂 [Fold 4/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 3048.53
# [400]	valid_0's l1: 2783.84
# [600]	valid_0's l1: 2723.27
# [800]	valid_0's l1: 2646.47
# [1000]	valid_0's l1: 2603.89
# [1200]	valid_0's l1: 2567.75
# [1400]	valid_0's l1: 2539.69
# [0]	validation_0-mae:7420.57977
# [200]	validation_0-mae:3083.99477
# [400]	validation_0-mae:2840.69990
# [600]	validation_0-mae:2777.35327
# [800]	validation_0-mae:2750.79049
# [1000]	validation_0-mae:2733.80743
# [1200]	validation_0-mae:2719.85696
# [1400]	validation_0-mae:2702.58147
# [1499]	validation_0-mae:2695.91503
# 0:	learn: 5226.5369934	test: 7395.2856327	best: 7395.2856327 (0)	total: 13.2ms	remaining: 26.3s
# 300:	learn: 3044.7997370	test: 2312.9538380	best: 2312.9538380 (300)	total: 3.84s	remaining: 21.7s
# 600:	learn: 2939.1986927	test: 2237.4843648	best: 2237.4843648 (600)	total: 7.23s	remaining: 16.8s
# 900:	learn: 2842.7479999	test: 2192.1127298	best: 2192.0884190 (899)	total: 10.6s	remaining: 13s
# 1200:	learn: 2758.3637426	test: 2159.8153015	best: 2159.8153015 (1200)	total: 14.1s	remaining: 9.38s
# 1500:	learn: 2692.6371024	test: 2138.7667573	best: 2138.7667573 (1500)	total: 17.6s	remaining: 5.84s
# 1800:	learn: 2641.4748445	test: 2120.6402155	best: 2120.6402155 (1800)	total: 21s	remaining: 2.32s
# 1999:	learn: 2613.5832784	test: 2111.1554962	best: 2111.1554962 (1999)	total: 23.3s	remaining: 0us
#
# bestTest = 2111.155496
# bestIteration = 1999
#
#
# ▶ 📂 [Fold 5/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 3010.8
# [400]	valid_0's l1: 2738.19
# [600]	valid_0's l1: 2651.33
# [800]	valid_0's l1: 2580.63
# [1000]	valid_0's l1: 2531.68
# [1200]	valid_0's l1: 2511.26
# [1400]	valid_0's l1: 2491.95
# [0]	validation_0-mae:7371.77357
# [200]	validation_0-mae:3044.41637
# [400]	validation_0-mae:2794.67258
# [600]	validation_0-mae:2731.50889
# [800]	validation_0-mae:2699.18121
# [1000]	validation_0-mae:2680.66522
# [1200]	validation_0-mae:2668.49372
# [1400]	validation_0-mae:2662.41620
# [1499]	validation_0-mae:2657.15053
# 0:	learn: 5219.8404017	test: 7348.6449171	best: 7348.6449171 (0)	total: 12.7ms	remaining: 25.3s
# 300:	learn: 3046.4721788	test: 2289.9941010	best: 2289.9941010 (300)	total: 3.6s	remaining: 20.3s
# 600:	learn: 2956.4219167	test: 2227.6632336	best: 2227.6632336 (600)	total: 6.95s	remaining: 16.2s
# 900:	learn: 2846.7646366	test: 2189.5477174	best: 2189.5477174 (900)	total: 10.4s	remaining: 12.7s
# 1200:	learn: 2754.0918001	test: 2165.0359767	best: 2165.0359767 (1200)	total: 13.8s	remaining: 9.21s
# 1500:	learn: 2690.3232451	test: 2150.4574086	best: 2150.4470116 (1496)	total: 17.3s	remaining: 5.74s
# 1800:	learn: 2639.0034256	test: 2139.1202082	best: 2139.1202082 (1800)	total: 20.7s	remaining: 2.29s
# 1999:	learn: 2610.7740763	test: 2133.5660539	best: 2133.5660539 (1999)	total: 23s	remaining: 0us
#
# bestTest = 2133.566054
# bestIteration = 1999
#
#
# ==================== 🎯 TARGET: kpx_group_3 훈련 시작 ====================
#
# ▶ 📂 [Fold 1/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2872.63
# [400]	valid_0's l1: 2611.07
# [600]	valid_0's l1: 2461.2
# [800]	valid_0's l1: 2404.81
# [1000]	valid_0's l1: 2391.53
# [1200]	valid_0's l1: 2370.79
# [1400]	valid_0's l1: 2348.24
# [0]	validation_0-mae:6427.77352
# [200]	validation_0-mae:2912.16089
# [400]	validation_0-mae:2693.56235
# [600]	validation_0-mae:2637.91916
# [800]	validation_0-mae:2616.03441
# [1000]	validation_0-mae:2604.38626
# [1200]	validation_0-mae:2585.82248
# [1400]	validation_0-mae:2574.66975
# [1499]	validation_0-mae:2569.43208
# 0:	learn: 4457.2987299	test: 6401.5816564	best: 6401.5816564 (0)	total: 12.6ms	remaining: 25.3s
# 300:	learn: 2906.6621204	test: 2110.8762405	best: 2110.8762405 (300)	total: 3.66s	remaining: 20.7s
# 600:	learn: 2808.5654964	test: 2052.6641605	best: 2052.6641605 (600)	total: 7.09s	remaining: 16.5s
# 900:	learn: 2712.5286128	test: 2012.3242925	best: 2012.3242925 (900)	total: 10.5s	remaining: 12.8s
# 1200:	learn: 2637.1892139	test: 1986.2615176	best: 1986.2615176 (1200)	total: 14s	remaining: 9.3s
# 1500:	learn: 2581.5853769	test: 1968.7633299	best: 1968.7633299 (1500)	total: 17.4s	remaining: 5.8s
# 1800:	learn: 2536.7056179	test: 1958.2436692	best: 1958.2436692 (1800)	total: 20.9s	remaining: 2.31s
# 1999:	learn: 2507.7902191	test: 1951.0904203	best: 1951.0904203 (1999)	total: 23.2s	remaining: 0us
#
# bestTest = 1951.09042
# bestIteration = 1999
#
#
# ▶ 📂 [Fold 2/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2987.89
# [400]	valid_0's l1: 2750.78
# [600]	valid_0's l1: 2572.22
# [800]	valid_0's l1: 2473.63
# [1000]	valid_0's l1: 2441.31
# [1200]	valid_0's l1: 2415.38
# [1400]	valid_0's l1: 2388
# [0]	validation_0-mae:6503.62109
# [200]	validation_0-mae:3007.47668
# [400]	validation_0-mae:2795.72866
# [600]	validation_0-mae:2746.68418
# [800]	validation_0-mae:2713.98686
# [1000]	validation_0-mae:2688.71415
# [1200]	validation_0-mae:2671.27848
# [1400]	validation_0-mae:2647.95240
# [1499]	validation_0-mae:2641.07604
# 0:	learn: 4420.5448940	test: 6476.5612143	best: 6476.5612143 (0)	total: 12.4ms	remaining: 24.8s
# 300:	learn: 2886.7706514	test: 2181.9907591	best: 2181.9907591 (300)	total: 3.65s	remaining: 20.6s
# 600:	learn: 2791.8223744	test: 2123.8770703	best: 2123.8770703 (600)	total: 7.05s	remaining: 16.4s
# 900:	learn: 2691.9481462	test: 2090.6983776	best: 2090.6919798 (899)	total: 10.5s	remaining: 12.8s
# 1200:	learn: 2631.2058849	test: 2073.7131885	best: 2073.7131885 (1200)	total: 14s	remaining: 9.32s
# 1500:	learn: 2575.6987314	test: 2056.9973921	best: 2056.9472537 (1499)	total: 17.5s	remaining: 5.8s
# 1800:	learn: 2525.8859919	test: 2042.9518515	best: 2042.9518515 (1800)	total: 20.9s	remaining: 2.31s
# 1999:	learn: 2496.5950003	test: 2033.6778774	best: 2033.6778774 (1999)	total: 23.2s	remaining: 0us
#
# bestTest = 2033.677877
# bestIteration = 1999
#
#
# ▶ 📂 [Fold 3/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2962.08
# [400]	valid_0's l1: 2714.11
# [600]	valid_0's l1: 2543.43
# [800]	valid_0's l1: 2474.04
# [1000]	valid_0's l1: 2435.51
# [1200]	valid_0's l1: 2415.36
# [1400]	valid_0's l1: 2378.13
# [0]	validation_0-mae:6346.31078
# [200]	validation_0-mae:2986.79016
# [400]	validation_0-mae:2772.44475
# [600]	validation_0-mae:2724.97890
# [800]	validation_0-mae:2687.82450
# [1000]	validation_0-mae:2655.49095
# [1200]	validation_0-mae:2636.35730
# [1400]	validation_0-mae:2618.57191
# [1499]	validation_0-mae:2609.78303
# 0:	learn: 4471.3729099	test: 6321.3635751	best: 6321.3635751 (0)	total: 12.2ms	remaining: 24.3s
# 300:	learn: 2871.9876946	test: 2179.0566812	best: 2179.0566812 (300)	total: 3.71s	remaining: 20.9s
# 600:	learn: 2783.5550739	test: 2129.4960588	best: 2129.4960588 (600)	total: 7.2s	remaining: 16.8s
# 900:	learn: 2680.5045743	test: 2092.5399563	best: 2092.5399563 (900)	total: 10.6s	remaining: 13s
# 1200:	learn: 2609.1470953	test: 2072.2938650	best: 2072.2900102 (1199)	total: 14.1s	remaining: 9.39s
# 1500:	learn: 2558.4980896	test: 2058.6496603	best: 2058.6346027 (1491)	total: 17.6s	remaining: 5.85s
# 1800:	learn: 2517.3056066	test: 2049.5957355	best: 2049.5636232 (1798)	total: 21.2s	remaining: 2.34s
# 1999:	learn: 2493.7993857	test: 2044.4604319	best: 2044.4344125 (1986)	total: 23.5s	remaining: 0us
#
# bestTest = 2044.434412
# bestIteration = 1986
#
# Shrink model to first 1987 iterations.
#
# ▶ 📂 [Fold 4/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2943.89
# [400]	valid_0's l1: 2690.09
# [600]	valid_0's l1: 2557.75
# [800]	valid_0's l1: 2484.79
# [1000]	valid_0's l1: 2414.26
# [1200]	valid_0's l1: 2388.41
# [1400]	valid_0's l1: 2363.68
# [0]	validation_0-mae:6494.22091
# [200]	validation_0-mae:2966.91628
# [400]	validation_0-mae:2750.56311
# [600]	validation_0-mae:2686.89323
# [800]	validation_0-mae:2658.39250
# [1000]	validation_0-mae:2637.05474
# [1200]	validation_0-mae:2610.31146
# [1400]	validation_0-mae:2600.56913
# [1499]	validation_0-mae:2595.36286
# 0:	learn: 4457.2913427	test: 6469.3098436	best: 6469.3098436 (0)	total: 12.5ms	remaining: 25s
# 300:	learn: 2892.8878837	test: 2100.6049196	best: 2100.6049196 (300)	total: 3.65s	remaining: 20.6s
# 600:	learn: 2797.8335941	test: 2035.7668434	best: 2035.7668434 (600)	total: 7.1s	remaining: 16.5s
# 900:	learn: 2697.2297716	test: 1993.5916523	best: 1993.5916523 (900)	total: 10.6s	remaining: 13s
# 1200:	learn: 2608.7002726	test: 1967.4648731	best: 1967.4640202 (1198)	total: 14.2s	remaining: 9.42s
# 1500:	learn: 2553.8671282	test: 1950.7028588	best: 1950.7028588 (1500)	total: 17.7s	remaining: 5.9s
# 1800:	learn: 2502.7030141	test: 1938.6502590	best: 1938.6268751 (1799)	total: 21.3s	remaining: 2.35s
# 1999:	learn: 2477.3843655	test: 1934.2873273	best: 1934.1255202 (1991)	total: 23.6s	remaining: 0us
#
# bestTest = 1934.12552
# bestIteration = 1991
#
# Shrink model to first 1992 iterations.
#
# ▶ 📂 [Fold 5/5] 내부 분할 학습 진행 중...
# [200]	valid_0's l1: 2892.41
# [400]	valid_0's l1: 2662.77
# [600]	valid_0's l1: 2476.74
# [800]	valid_0's l1: 2392.53
# [1000]	valid_0's l1: 2350.38
# [1200]	valid_0's l1: 2324.65
# [1400]	valid_0's l1: 2305.79
# [0]	validation_0-mae:6474.09343
# [200]	validation_0-mae:2917.53114
# [400]	validation_0-mae:2699.21900
# [600]	validation_0-mae:2648.82030
# [800]	validation_0-mae:2623.50227
# [1000]	validation_0-mae:2608.82807
# [1200]	validation_0-mae:2593.37741
# [1400]	validation_0-mae:2572.32902
# [1499]	validation_0-mae:2568.03299
# 0:	learn: 4441.9934298	test: 6448.6499090	best: 6448.6499090 (0)	total: 12.6ms	remaining: 25.3s
# 300:	learn: 2924.5384408	test: 2051.5396519	best: 2051.5396519 (300)	total: 3.69s	remaining: 20.8s
# 600:	learn: 2830.4904299	test: 1996.9091418	best: 1996.9091418 (600)	total: 7.14s	remaining: 16.6s
# 900:	learn: 2732.7746838	test: 1967.1840503	best: 1967.1840503 (900)	total: 10.7s	remaining: 13s
# 1200:	learn: 2662.6221226	test: 1948.0184814	best: 1948.0184814 (1200)	total: 14.2s	remaining: 9.44s
# 1500:	learn: 2596.8088494	test: 1927.2542475	best: 1927.2542475 (1500)	total: 17.9s	remaining: 5.96s
# 1800:	learn: 2543.7473399	test: 1912.4648786	best: 1912.4425940 (1799)	total: 21.6s	remaining: 2.38s
# 1999:	learn: 2511.4770283	test: 1905.7464924	best: 1905.7078187 (1998)	total: 23.9s	remaining: 0us
#
# bestTest = 1905.707819
# bestIteration = 1998
#
# Shrink model to first 1999 iterations.
#
# 🏆 [성공] 변수 누락 지뢰가 완전히 박멸되었습니다! 이어서 최적화 블렌딩 셀(7번)을 구동해 주세요.

# %% [markdown]
# ## 6. 테스트 데이터 예측 생성
#
# 학습한 그룹별 모델로 평가 기간 전체의 발전량을 예측합니다. 예측값은 0 이상, 설비 용량 이하로 클리핑하여
# 물리적으로 불가능한 값을 방지합니다.

# %%
# =====================================================================
# 🎯 [6번 셀 완전체] 타깃별 독립 가중치 최적화 및 테스트 예측 프레임 수혈
# =====================================================================
from scipy.optimize import minimize
import numpy as np
import pandas as pd

print("⏳ 1. 데이콘 공식 평가 산식(metric) 함수 정의 중...")
def metric(answer_df, pred_df):
    group_nmae = []
    group_ficr = []
    for col in TARGET_COLS:
        actual = answer_df[col].to_numpy(dtype=float)
        forecast = pred_df[col].to_numpy(dtype=float)
        capacity = CAPACITY_KWH[col]
        valid = actual >= capacity * 0.10
        actual = actual[valid]
        forecast = forecast[valid]
        
        error_rate = np.abs(forecast - actual) / capacity
        group_nmae.append(np.mean(error_rate))
        unit_price = np.select([error_rate <= 0.06, error_rate <= 0.08], [4.0, 3.0], default=0.0)
        group_ficr.append(np.sum(actual * unit_price) / np.sum(actual * 4.0))
    return 0.5 * (1 - np.mean(group_nmae)) + 0.5 * np.mean(group_ficr), 1 - np.mean(group_nmae), np.mean(group_ficr)

print("🔍 2. 각 발전 그룹별(kpx_group_1/2/3) 최적화 블렌딩 가중치 독립 탐색 시작...")
answer_df = valid_set[TARGET_COLS].copy()

# 최종 앙상블 프레임 레이어 선언 (NameError 방지)
pred_df_final_blend = pd.DataFrame(index=valid_set.index, columns=TARGET_COLS)
final_test_predictions = pd.DataFrame(index=sample_submission.index, columns=TARGET_COLS)

best_weights_by_target = {}

for target in TARGET_COLS:
    target_capacity = CAPACITY_KWH[target]
    
    # 🎯 해당 타깃의 단일 하이브리드 스코어를 타격하는 목적 함수 정의
    def objective_single_target(weights):
        w_lgb, w_xgb, w_cat = weights
        blend_val = (w_lgb * valid_preds_lgb[target] + 
                     w_xgb * valid_preds_xgb[target] + 
                     w_cat * valid_preds_cat[target])
        blend_clipped = np.clip(blend_val, 0, target_capacity)
        
        actual = answer_df[target].to_numpy(dtype=float)
        forecast = blend_clipped
        valid = actual >= target_capacity * 0.10
        
        if np.sum(valid) == 0: 
            return 1.0
            
        error_rate = np.abs(forecast[valid] - actual[valid]) / target_capacity
        nmae_score = 1.0 - np.mean(error_rate)
        unit_price = np.select([error_rate <= 0.06, error_rate <= 0.08], [4.0, 3.0], default=0.0)
        ficr_score = np.sum(actual[valid] * unit_price) / np.sum(actual[valid] * 4.0)
        
        return 1.0 - (0.5 * nmae_score + 0.5 * ficr_score)

    cons = ({'type': 'eq', 'fun': lambda w: 1.0 - sum(w)})
    bounds = [(0, 1), (0, 1), (0, 1)]
    init_weights = [0.4, 0.3, 0.3]
    
    res = minimize(objective_single_target, init_weights, method='SLSQP', bounds=bounds, constraints=cons)
    best_weights_by_target[target] = res.x
    
    print(f" ▶ [{target}] 독립 가중치 완공 -> LGBM: {res.x[0]:.4f} | XGB: {res.x[1]:.4f} | CAT: {res.x[2]:.4f}")
    
    w_lgb, w_xgb, w_cat = res.x
    # 검증셋 블렌딩값 조립
    pred_df_final_blend[target] = np.clip(w_lgb * valid_preds_lgb[target] + w_xgb * valid_preds_xgb[target] + w_cat * valid_preds_cat[target], 0, target_capacity)
    # 테스트셋 최종 예측 수혈
    final_test_predictions[target] = np.clip(w_lgb * final_preds_lgb[target] + w_xgb * final_preds_xgb[target] + w_cat * final_preds_cat[target], 0, target_capacity)

print("\n⏳ 3. 테스트 데이터 제출 프레임 동기화 매핑 중...")
submission = sample_submission[["forecast_id", "forecast_kst_dtm"]].copy()
for target in TARGET_COLS:
    submission[target] = final_test_predictions[target]

submission["forecast_kst_dtm"] = pd.to_datetime(submission["forecast_kst_dtm"]).dt.strftime("%Y-%m-%d %H:%M:%S")

print("\n📊 [완공] 수리적 타깃 분리 매핑 완료!")
print(submission.head())
# Out:
# ⏳ 1. 데이콘 공식 평가 산식(metric) 함수 정의 중...
# 🔍 2. 각 발전 그룹별(kpx_group_1/2/3) 최적화 블렌딩 가중치 독립 탐색 시작...
#  ▶ [kpx_group_1] 독립 가중치 완공 -> LGBM: 0.4317 | XGB: 0.3991 | CAT: 0.1692
#  ▶ [kpx_group_2] 독립 가중치 완공 -> LGBM: 0.4006 | XGB: 0.3011 | CAT: 0.2983
#  ▶ [kpx_group_3] 독립 가중치 완공 -> LGBM: 0.4000 | XGB: 0.3000 | CAT: 0.3000
#
# ⏳ 3. 테스트 데이터 제출 프레임 동기화 매핑 중...
#
# 📊 [완공] 수리적 타깃 분리 매핑 완료!
#      forecast_id     forecast_kst_dtm   kpx_group_1   kpx_group_2  \
# 0  forecast_0001  2025-01-01 01:00:00  18532.917570  19135.913697
# 1  forecast_0002  2025-01-01 02:00:00  18121.385309  19132.111010
# 2  forecast_0003  2025-01-01 03:00:00  16921.293850  19172.246086
# 3  forecast_0004  2025-01-01 04:00:00  16855.745516  19235.149366
# 4  forecast_0005  2025-01-01 05:00:00  16524.196784  19257.089118
#
#     kpx_group_3
# 0  16068.723280
# 1  15697.381324
# 2  15591.283341
# 3  15227.326812
# 4  15110.647257

# %% [markdown]
# ## 7. 평가 산식

# %%
# =====================================================================
# [무결성 보정 완공] 7번 셀: KPX 발전그룹별 세부 성능 정밀 리포트
# =====================================================================

def print_target_specific_report(answer_df, pred_df):
    print("======================================================================")
    print("🏆 TARGET-SPECIFIC ENSEMBLE DETAILED PERFORMANCE REPORT")
    print("======================================================================\n")
    
    total_nmae = []
    total_ficr = []
    
    for col in TARGET_COLS:
        actual = answer_df[col].to_numpy(dtype=float)
        forecast = pred_df[col].to_numpy(dtype=float)
        capacity = CAPACITY_KWH[col]
        
        # 10% 이상인 유효 구간 플래깅
        valid = actual >= capacity * 0.10
        
        if np.sum(valid) == 0:
            print(f"▶ 🏢 [{col}] 유효한 검증 데이터가 없습니다.")
            continue
            
        actual_v = actual[valid]
        forecast_v = forecast[valid]
        
        # NMAE 및 FICR 계산
        error_rate = np.abs(forecast_v - actual_v) / capacity
        nmae_score = np.mean(error_rate)
        one_minus_nmae = 1.0 - nmae_score
        
        unit_price = np.select([error_rate <= 0.06, error_rate <= 0.08], [4.0, 3.0], default=0.0)
        ficr_score = np.sum(actual_v * unit_price) / np.sum(actual_v * 4.0)
        
        # 그룹별 최종 단일 스코어
        group_score = 0.5 * swimming_score if 'swimming_score' in globals() else 0.5 * (one_minus_nmae + ficr_score)
        
        total_nmae.append(nmae_score)
        total_ficr.append(ficr_score)
        
        print(f"🏢 [발전 그룹: {col}] 설비 용량: {capacity} kWh")
        print(f"  - 🎯 그룹 자체 최종 점수 (Score) : {group_score:.5f}")
        print(f"  - 📈 1 - NMAE (예측 정확도)     : {one_minus_nmae:.5f} (오차율: {nmae_score*100:.2f}%)")
        print(f"  - 💰 정산금획득률 (FICR)         : {ficr_score:.5f}")
        print("-" * 70)
        
    final_total = 0.5 * (1 - np.mean(total_nmae)) + 0.5 * np.mean(total_ficr)
    print(f"\n🚀 [앙상블 최종 통합 점수 (Total Score)] : {final_total:.5f}")
    print(f"💡 무결성 검증 완공! 이제 8번 셀을 실행하여 csv 파일로 빌드하시면 됩니다.")
    print("======================================================================")

# 스캐너 구동
print_target_specific_report(answer_df, pred_df_final_blend)
# Out:
# ======================================================================
# 🏆 TARGET-SPECIFIC ENSEMBLE DETAILED PERFORMANCE REPORT
# ======================================================================
#
# 🏢 [발전 그룹: kpx_group_1] 설비 용량: 21600 kWh
#   - 🎯 그룹 자체 최종 점수 (Score) : 0.60279
#   - 📈 1 - NMAE (예측 정확도)     : 0.87801 (오차율: 12.20%)
#   - 💰 정산금획득률 (FICR)         : 0.32758
# ----------------------------------------------------------------------
# 🏢 [발전 그룹: kpx_group_2] 설비 용량: 21600 kWh
#   - 🎯 그룹 자체 최종 점수 (Score) : 0.64878
#   - 📈 1 - NMAE (예측 정확도)     : 0.87790 (오차율: 12.21%)
#   - 💰 정산금획득률 (FICR)         : 0.41965
# ----------------------------------------------------------------------
# 🏢 [발전 그룹: kpx_group_3] 설비 용량: 21000 kWh
#   - 🎯 그룹 자체 최종 점수 (Score) : 0.57266
#   - 📈 1 - NMAE (예측 정확도)     : 0.86320 (오차율: 13.68%)
#   - 💰 정산금획득률 (FICR)         : 0.28212
# ----------------------------------------------------------------------
#
# 🚀 [앙상블 최종 통합 점수 (Total Score)] : 0.60808
# 💡 무결성 검증 완공! 이제 8번 셀을 실행하여 csv 파일로 빌드하시면 됩니다.
# ======================================================================

# %% [markdown]
# ## 8. baseline_submit.csv 생성
#
# `sample_submission.csv` 형식에 맞춰 최종 제출 파일을 생성합니다. 이 대회는 결과 CSV를 직접 제출하는
# 방식이므로, 이 파일을 그대로 제출하면 됩니다.

# %%
output_path = DATA_DIR / "baseline_submit.csv"
submission.to_csv(output_path, index=False, encoding="utf-8-sig")
print(f"Saved: {output_path}")
# Out:
# Saved: C:\Users\user\iCloudDrive\riversun\동국대학교\3학년 1학기\대외활동\DACON\데이터\open\baseline_submit.csv

# %%
import pandas as pd
import numpy as np

# 조사할 데이터셋 전체 등록
dfs_to_check = {
    "Train Labels": train_labels,
    "LDAPS Train": ldaps_train,
    "GFS Train": gfs_train,
    "SCADA Vestas": scada_vestas,
    "SCADA Unison": scada_unison
}

print("======================================================================")
print("🔍 [전수조사] 모든 데이터셋 컬럼별 이상치 & 노이즈 탐지 리포트")
print("======================================================================\n")

for name, df in dfs_to_check.items():
    print(f"📂 [데이터셋] {name} | 📐 크기: {df.shape}")
    print("-" * 70)
    
    # 수치형 컬럼만 추출
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    
    if len(numeric_cols) == 0:
        print("ℹ️ 수치형 컬럼이 존재하지 않습니다.\n")
        continue
        
    # 각 컬럼별 통계량 및 결측치 수집
    report_data = []
    for col in numeric_cols:
        # 결측치 계산
        null_cnt = df[col].isnull().sum()
        null_pct = (null_cnt / len(df)) * 100
        
        # 통계량 계산
        c_min = df[col].min()
        c_max = df[col].max()
        c_mean = df[col].mean()
        
        # 특이 변동성 (표준편차가 0이거나 미세한 경우 탐지)
        c_std = df[col].std()
        
        report_data.append({
            "Column Name": col,
            "Missing(Count)": null_cnt,
            "Missing(%)": f"{null_pct:.2f}%",
            "Min": round(c_min, 4),
            "Max": round(c_max, 4),
            "Mean": round(c_mean, 4),
            "Std": round(c_std, 4) if not np.isnan(c_std) else 0.0
        })
    
    # 데이터프레임으로 변환하여 깔끔하게 출력
    report_df = pd.DataFrame(report_data)
    
    # 🎯 이상치가 강력하게 의심되는 컬럼들을 가독성 좋게 보기 위해 판다스 출력 옵션 조정
    pd.set_option('display.max_rows', None)  # 모든 컬럼 다 찍기
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)
    
    print(report_df.to_string(index=False))
    print("======================================================================\n")
# Out:
# ======================================================================
# 🔍 [전수조사] 모든 데이터셋 컬럼별 이상치 & 노이즈 탐지 리포트
# ======================================================================
#
# 📂 [데이터셋] Train Labels | 📐 크기: (26304, 4)
# ----------------------------------------------------------------------
# Column Name  Missing(Count) Missing(%)  Min       Max      Mean       Std
# kpx_group_1             104      0.40%  0.0 21275.305 6621.9811 6582.4431
# kpx_group_2             103      0.39%  0.0 21362.084 7076.8429 7001.1461
# kpx_group_3            8766     33.33%  0.0 21130.674 5563.8196 6294.5829
# ======================================================================
#
# 📂 [데이터셋] LDAPS Train | 📐 크기: (420864, 35)
# ----------------------------------------------------------------------
#                  Column Name  Missing(Count) Missing(%)        Min         Max        Mean      Std
#                      grid_id               0      0.00%     1.0000     16.0000      8.5000   4.6098
#                     latitude               0      0.00%    37.2607     37.3032     37.2819   0.0138
#                    longitude               0      0.00%   128.9257    128.9958    128.9607   0.0213
#     heightAboveGround_10_10u               0      0.00%   -11.8255     18.0860      2.7390   4.3329
#     heightAboveGround_10_10v               0      0.00%   -17.3449     12.7115      0.4254   1.9380
# heightAboveGround_50_50MUmax               0      0.00%   -17.2054     29.1335      4.6964   6.5602
# heightAboveGround_50_50MUmin               0      0.00%   -19.5501     27.4754      3.6054   6.5546
# heightAboveGround_50_50MVmax               0      0.00%   -24.6943     20.7730      1.1452   3.0498
# heightAboveGround_50_50MVmin               0      0.00%   -27.7741     18.7945      0.1564   2.9545
#    heightAboveGround_5_XBLWS               0      0.00%    -0.5354      0.9574      0.0249   0.0805
#    heightAboveGround_5_YBLWS               0      0.00%    -6.4863      3.7117      0.0603   0.3084
#        heightAboveGround_2_t               0      0.00%   249.6983    302.9151    281.1693  10.6387
#      heightAboveGround_2_dpt               0      0.00%   242.4148    297.3518    276.3669  12.0010
#        heightAboveGround_2_r               0      0.00%    11.0186    110.3845     75.4690  20.6670
#        heightAboveGround_2_q               0      0.00%     0.0002      0.0212      0.0070   0.0050
#                 surface_0_sp               0      0.00% 87462.8100  93083.1300  90673.4919 706.5050
#              meanSea_0_prmsl               0      0.00% 98038.9800 103395.0700 101454.2701 760.8344
#                    etc_0_blh               0      0.00%    11.9226   3850.2060    340.2303 292.9050
#              surface_0_NDNSW               0      0.00%     0.0000    948.9419    151.7969 231.1277
#              surface_0_NDNLW               0      0.00%  -179.5872     18.4404    -65.3811  40.7685
#    heightAboveGround_2_SWDIR               0      0.00%     0.0000    946.0156    120.1601 215.9791
#    heightAboveGround_2_SWDIF               0      0.00%     0.0000    541.0898     60.2099  84.0622
#                    etc_0_hcc               0      0.00%     0.0000      1.0000      0.2748   0.3678
#                    etc_0_mcc               0      0.00%     0.0000      1.0000      0.1816   0.3233
#                    etc_0_lcc               0      0.00%     0.0000      1.0000      0.2961   0.3831
#                  etc_0_VLCDC               0      0.00%     0.0000      1.0000      0.1676   0.3162
#        surface_0_avg_lsprate               0      0.00%     0.0000      0.0245      0.0000   0.0003
#            surface_0_lssrate               0      0.00%     0.0000      0.0016      0.0000   0.0001
#              surface_0_ncpcp               0      0.00%     0.0000     88.3106      0.1570   1.2552
#               surface_0_snol               0      0.00%     0.0000      5.7109      0.0232   0.1819
#               surface_0_SNOM               0      0.00%    -0.0000      6.6069      0.0134   0.1320
#                surface_0_lsm               0      0.00%     1.0000      1.0000      1.0000   0.0000
#                  surface_0_h               0      0.00%   868.8125   1001.2500    943.5273  43.3686
# ======================================================================
#
# 📂 [데이터셋] GFS Train | 📐 크기: (236736, 40)
# ----------------------------------------------------------------------
#                    Column Name  Missing(Count) Missing(%)        Min         Max        Mean       Std
#                        grid_id               0      0.00%     1.0000      9.0000      5.0000    2.5820
#                       latitude               0      0.00%    37.0000     37.5000     37.2500    0.2041
#                      longitude               0      0.00%   128.7500    129.2500    129.0000    0.2041
#       heightAboveGround_10_10u               0      0.00%   -17.1836     17.8276      1.2377    2.3127
#       heightAboveGround_10_10v               0      0.00%   -24.2439     15.4641      0.1776    1.7322
#         heightAboveGround_80_u               0      0.00%   -21.8138     25.6597      1.9280    3.4303
#         heightAboveGround_80_v               0      0.00%   -30.7273     19.6237      0.2226    2.3626
#     heightAboveGround_100_100u               0      0.00%   -22.4202     27.1495      2.0256    3.5971
#     heightAboveGround_100_100v               0      0.00%   -31.5098     20.1127      0.2285    2.4498
#         heightAboveGround_2_2t               0      0.00%   251.1017    308.4000    283.5625   10.3918
#         heightAboveGround_2_2d               0      0.00%   243.3147    298.7771    277.6539   11.7485
#         heightAboveGround_2_2r               0      0.00%    11.4000    100.0000     70.3283   21.5293
#        heightAboveGround_2_2sh               0      0.00%     0.0003      0.0209      0.0072    0.0050
#     planetaryBoundaryLayer_0_u               0      0.00%   -28.4242     40.6436      2.5623    4.9749
#     planetaryBoundaryLayer_0_v               0      0.00%   -35.5089     29.5178      0.1094    2.9922
# planetaryBoundaryLayer_0_VRATE               0      0.00%     0.0000  80000.0000   3497.8999 6531.4020
#                surface_0_dswrf               0      0.00%     0.0000    938.3200    179.5058  245.1378
#                surface_0_dlwrf               0      0.00%   128.2634    447.8611    303.3820   71.7973
#                surface_0_prate               0      0.00%     0.0000      0.0091      0.0000    0.0002
#                   surface_0_tp               0      0.00%     0.0000    228.6250      2.3262    8.9706
#                   surface_0_sp               0      0.00% 90569.8360 103344.3300  95444.0770 2745.6337
#                meanSea_0_prmsl               0      0.00% 98440.0400 103858.4900 101635.3776  785.0043
#                 surface_0_gust               0      0.00%     0.0182     30.5105      4.3733    4.0311
#            lowCloudLayer_0_lcc               0      0.00%     0.0000    100.0000     26.5903   37.8345
#         middleCloudLayer_0_mcc               0      0.00%     0.0000    100.0000     26.9624   39.8784
#           highCloudLayer_0_hcc               0      0.00%     0.0000    100.0000     38.6294   44.0746
#               atmosphere_0_tcc               0      0.00%     0.0000    100.0000     55.9040   43.4789
#            isobaricInhPa_850_t               0      0.00%   247.1055    297.8268    279.1217   10.1774
#            isobaricInhPa_850_u               0      0.00%   -29.7027     46.6468      5.2295    7.1331
#            isobaricInhPa_850_v               0      0.00%   -40.4395     35.6677     -0.4200    4.7083
#            isobaricInhPa_850_r               0      0.00%     1.5000    100.0000     60.3515   28.4279
#            isobaricInhPa_700_t               0      0.00%   242.8393    290.1739    272.1421    9.1852
#            isobaricInhPa_700_u               0      0.00%   -27.7923     44.0070      9.1602    7.8879
#            isobaricInhPa_700_v               0      0.00%   -29.9685     39.1090     -1.2562    6.6311
#           isobaricInhPa_500_gh               0      0.00%  5048.8926   5973.1960   5662.8864  159.1271
#            isobaricInhPa_500_t               0      0.00%   229.7652    275.6709    257.2520    9.0001
#            isobaricInhPa_500_u               0      0.00%   -23.0236     71.9605     17.2606   11.2663
#            isobaricInhPa_500_v               0      0.00%   -40.9669     39.7565     -0.8885    8.4212
# ======================================================================
#
# 📂 [데이터셋] SCADA Vestas | 📐 크기: (157819, 39)
# ----------------------------------------------------------------------
#              Column Name  Missing(Count) Missing(%)         Min          Max     Mean         Std
# vestas_wtg01_power_kw10m               0      0.00% -42512957.0 4.251296e+07 195.4721 712805.8702
# vestas_wtg02_power_kw10m               0      0.00% -41959813.0 4.195981e+07 201.2891 691914.9474
# vestas_wtg03_power_kw10m               0      0.00% -46559445.0 4.655944e+07 217.4578 786801.1489
# vestas_wtg04_power_kw10m               0      0.00% -40642699.0 4.064270e+07 186.6338 480318.3805
# vestas_wtg05_power_kw10m               0      0.00% -33717814.0 3.371781e+07 153.1888 456684.6636
# vestas_wtg06_power_kw10m               0      0.00% -34184409.0 3.418441e+07 158.1881 478422.4268
# vestas_wtg07_power_kw10m               0      0.00% -29770834.0 2.977083e+07 138.3776 418071.3258
# vestas_wtg08_power_kw10m               0      0.00% -42301001.0 4.230100e+07 185.3734 802538.1791
# vestas_wtg09_power_kw10m               0      0.00% -43556999.0 4.355699e+07 199.2562 580428.7408
# vestas_wtg10_power_kw10m               0      0.00% -51376454.0 5.137645e+07 239.2066 842549.6325
# vestas_wtg11_power_kw10m               0      0.00% -51770425.0 5.177042e+07 222.9797 996905.7232
# vestas_wtg12_power_kw10m               0      0.00% -41447795.0 4.144780e+07 198.8042 627046.5915
#          vestas_wtg01_ws               0      0.00%         0.0 2.280000e+01   7.0479      3.7345
#          vestas_wtg02_ws               0      0.00%         0.0 2.712500e+01   7.0386      3.8588
#          vestas_wtg03_ws               0      0.00%         0.0 2.760500e+01   7.2907      3.9699
#          vestas_wtg04_ws               0      0.00%         0.0 2.633600e+01   6.8173      3.5642
#          vestas_wtg05_ws               0      0.00%         0.0 2.230000e+01   6.1015      3.4636
#          vestas_wtg06_ws               0      0.00%         0.0 2.398000e+01   6.4009      3.3541
#          vestas_wtg07_ws               0      0.00%         0.0 2.158600e+01   5.9770      3.0853
#          vestas_wtg08_ws               0      0.00%         0.0 2.729300e+01   6.9022      3.7840
#          vestas_wtg09_ws               0      0.00%         0.0 2.634400e+01   7.1516      3.8954
#          vestas_wtg10_ws               0      0.00%         0.0 3.075000e+01   7.9855      4.5310
#          vestas_wtg11_ws               0      0.00%         0.0 3.111700e+01   7.9982      4.6259
#          vestas_wtg12_ws               0      0.00%         0.0 2.750400e+01   7.2035      4.1444
#          vestas_wtg01_wd               0      0.00%         0.0 3.590000e+02 208.2840     94.9831
#          vestas_wtg02_wd               0      0.00%         0.0 3.590000e+02 203.8239     87.8198
#          vestas_wtg03_wd               0      0.00%         0.0 3.590000e+02 216.4440     87.8917
#          vestas_wtg04_wd               0      0.00%         0.0 3.590000e+02 227.0207     95.0603
#          vestas_wtg05_wd               0      0.00%         0.0 3.590000e+02 194.1693     97.0672
#          vestas_wtg06_wd               0      0.00%         0.0 3.590000e+02 210.2954     91.3377
#          vestas_wtg07_wd               0      0.00%         0.0 3.590000e+02 201.2466     89.4278
#          vestas_wtg08_wd               0      0.00%         0.0 3.590000e+02 207.3592     87.7264
#          vestas_wtg09_wd               0      0.00%         0.0 3.590000e+02 215.9621     89.5592
#          vestas_wtg10_wd               0      0.00%         0.0 3.590000e+02 205.1566     89.1215
#          vestas_wtg11_wd               0      0.00%         0.0 3.590000e+02 212.3076     91.2959
#          vestas_wtg12_wd               0      0.00%         0.0 3.590000e+02 183.3310     94.5275
#     turbine_ws_mean_calc               0      0.00%         0.0 2.565850e+01   6.9929      3.6101
#          turbine_ws_mean               0      0.00%         0.0 2.565850e+01   6.9929      3.6101
# ======================================================================
#
# 📂 [데이터셋] SCADA Unison | 📐 크기: (105264, 16)
# ----------------------------------------------------------------------
#              Column Name  Missing(Count) Missing(%)       Min       Max     Mean      Std
# unison_wtg01_power_kw10m             208      0.20%    0.0000  800.0000 162.7537 213.9657
# unison_wtg02_power_kw10m            1362      1.29%    0.0000 1000.0000 145.4110 209.5040
# unison_wtg03_power_kw10m             352      0.33%    0.0000  900.0000 201.0703 241.7476
# unison_wtg04_power_kw10m             150      0.14%    0.0000  800.0000 196.3902 239.2190
# unison_wtg05_power_kw10m             142      0.13%    0.0000  800.0000 221.5432 262.7191
#          unison_wtg01_ws            1466      1.39%    0.0000   22.1600   5.5097   3.2081
#          unison_wtg02_ws            1424      1.35%    0.1500   26.5200   5.1832   3.5999
#          unison_wtg03_ws             447      0.42%    0.1100   25.0400   5.9960   3.8961
#          unison_wtg04_ws             380      0.36%    0.0000   27.9800   6.0493   3.9275
#          unison_wtg05_ws            1379      1.31%    0.0000   32.0500   6.4285   4.1724
#          unison_wtg01_wd             208      0.20% -179.9980  179.9924 -35.3046  88.4939
#          unison_wtg02_wd            1354      1.29% -179.9908  179.9915 -29.8730  91.3222
#          unison_wtg03_wd             347      0.33% -179.9849  179.9793 -59.3135 100.8786
#          unison_wtg04_wd             152      0.14% -179.9993  179.9968 -38.7781  89.2797
#          unison_wtg05_wd             140      0.13% -179.9975  179.9940 -64.0238 104.6272
# ======================================================================

# %%
# === [독립 실행용] 데이터 무결성 및 단위 검증 스캐너 ===
print("==================================================")
print("🔍 [기압 및 풍속 단위 검증] 데이터 샘플 스냅샷")
print("==================================================")

if 'ldaps_train' in globals() and not ldaps_train.empty:
    p_col_ldaps = [c for c in ldaps_train.columns if '_sp' in c or 'press' in c.lower()]
    if p_col_ldaps:
        print(f"▶ LDAPS 기압 원본 [{p_col_ldaps[0]}] 최소/최대값: {ldaps_train[p_col_ldaps[0]].min()} ~ {ldaps_train[p_col_ldaps[0]].max()}")
        print(f"   (값의 스케일이 100,000 안팎이면 Pa, 1,000 안팎이면 hPa입니다.)")

if 'gfs_train' in globals() and not gfs_train.empty:
    p_col_gfs = [c for c in gfs_train.columns if '_sp' in c or 'press' in c.lower()]
    if p_col_gfs:
        print(f"▶ GFS 기압 원본 [{p_col_gfs[0]}] 최소/최대값: {gfs_train[p_col_gfs[0]].min()} ~ {gfs_train[p_col_gfs[0]].max()}\n")

print("==================================================")
print("🔍 [결측치 및 미사용 컬럼 탐지] 요약 리포트")
print("==================================================")
for name, df in [("LDAPS Train", ldaps_train), ("GFS Train", gfs_train), ("Vestas SCADA", scada_vestas), ("Unison SCADA", scada_unison)]:
    null_counts = df.isnull().sum().sum()
    print(f"📂 {name} 데이터셋 전체 크기: {df.shape} | 총 결측치 수: {null_counts}")
# Out:
# ==================================================
# 🔍 [기압 및 풍속 단위 검증] 데이터 샘플 스냅샷
# ==================================================
# ▶ LDAPS 기압 원본 [surface_0_sp] 최소/최대값: 87462.81 ~ 93083.13
#    (값의 스케일이 100,000 안팎이면 Pa, 1,000 안팎이면 hPa입니다.)
# ▶ GFS 기압 원본 [surface_0_sp] 최소/최대값: 90569.836 ~ 103344.33
#
# ==================================================
# 🔍 [결측치 및 미사용 컬럼 탐지] 요약 리포트
# ==================================================
# 📂 LDAPS Train 데이터셋 전체 크기: (420864, 35) | 총 결측치 수: 0
# 📂 GFS Train 데이터셋 전체 크기: (236736, 40) | 총 결측치 수: 0
# 📂 Vestas SCADA 데이터셋 전체 크기: (157819, 38) | 총 결측치 수: 0
# 📂 Unison SCADA 데이터셋 전체 크기: (105264, 16) | 총 결측치 수: 9511

# %%
# === [독립 실행용] 원본 기상 변수 이름 전수 추출 ===
if 'ldaps_train' in globals() and 'train_set' in globals():
    # 현재 학습 피처에 포함된 컬럼 키워드 추출
    used_cols = list(X_train.columns)
    
    print("==================================================")
    print("📂 LDAPS 원본 데이터셋의 전체 컬럼 목록 (총 35개)")
    print("==================================================")
    print(list(ldaps_train.columns))
    
    print("\n==================================================")
    print("📂 GFS 원본 데이터셋의 전체 컬럼 목록 (총 40개)")
    print("==================================================")
    print(list(gfs_train.columns))
# Out:
# ==================================================
# 📂 LDAPS 원본 데이터셋의 전체 컬럼 목록 (총 35개)
# ==================================================
# ['forecast_kst_dtm', 'data_available_kst_dtm', 'grid_id', 'latitude', 'longitude', 'heightAboveGround_10_10u', 'heightAboveGround_10_10v', 'heightAboveGround_50_50MUmax', 'heightAboveGround_50_50MUmin', 'heightAboveGround_50_50MVmax', 'heightAboveGround_50_50MVmin', 'heightAboveGround_5_XBLWS', 'heightAboveGround_5_YBLWS', 'heightAboveGround_2_t', 'heightAboveGround_2_dpt', 'heightAboveGround_2_r', 'heightAboveGround_2_q', 'surface_0_sp', 'meanSea_0_prmsl', 'etc_0_blh', 'surface_0_NDNSW', 'surface_0_NDNLW', 'heightAboveGround_2_SWDIR', 'heightAboveGround_2_SWDIF', 'etc_0_hcc', 'etc_0_mcc', 'etc_0_lcc', 'etc_0_VLCDC', 'surface_0_avg_lsprate', 'surface_0_lssrate', 'surface_0_ncpcp', 'surface_0_snol', 'surface_0_SNOM', 'surface_0_lsm', 'surface_0_h']
#
# ==================================================
# 📂 GFS 원본 데이터셋의 전체 컬럼 목록 (총 40개)
# ==================================================
# ['forecast_kst_dtm', 'data_available_kst_dtm', 'grid_id', 'latitude', 'longitude', 'heightAboveGround_10_10u', 'heightAboveGround_10_10v', 'heightAboveGround_80_u', 'heightAboveGround_80_v', 'heightAboveGround_100_100u', 'heightAboveGround_100_100v', 'heightAboveGround_2_2t', 'heightAboveGround_2_2d', 'heightAboveGround_2_2r', 'heightAboveGround_2_2sh', 'planetaryBoundaryLayer_0_u', 'planetaryBoundaryLayer_0_v', 'planetaryBoundaryLayer_0_VRATE', 'surface_0_dswrf', 'surface_0_dlwrf', 'surface_0_prate', 'surface_0_tp', 'surface_0_sp', 'meanSea_0_prmsl', 'surface_0_gust', 'lowCloudLayer_0_lcc', 'middleCloudLayer_0_mcc', 'highCloudLayer_0_hcc', 'atmosphere_0_tcc', 'isobaricInhPa_850_t', 'isobaricInhPa_850_u', 'isobaricInhPa_850_v', 'isobaricInhPa_850_r', 'isobaricInhPa_700_t', 'isobaricInhPa_700_u', 'isobaricInhPa_700_v', 'isobaricInhPa_500_gh', 'isobaricInhPa_500_t', 'isobaricInhPa_500_u', 'isobaricInhPa_500_v']

# %%
# === [독립 실행용] 고고도 기상 변수 단위 및 스케일 검증 스캐너 ===
print("======================================================================")
print("🔍 [GFS 고고도 변수 검증] 지상 80m/100m 바람 및 상층 기온")
print("======================================================================\n")

if 'gfs_train' in globals() and not gfs_train.empty:
    gfs_check_cols = [
        'heightAboveGround_80_u', 'heightAboveGround_80_v',
        'heightAboveGround_100_100u', 'heightAboveGround_100_100v',
        'isobaricInhPa_850_t'
    ]
    
    for col in gfs_check_cols:
        if col in gfs_train.columns:
            c_min = gfs_train[col].min()
            c_max = gfs_train[col].max()
            c_mean = gfs_train[col].mean()
            c_null = gfs_train[col].isnull().sum()
            print(f"▶ 컬럼명: {col}")
            print(f"   - 범위  : {c_min:.4f} ~ {c_max:.4f} (평균: {c_mean:.4f})")
            print(f"   - 결측치: {c_null}개")
            if '_t' in col:
                print(f"   💡 [기온 판정힌트] 평균이 250~300 사이면 캘빈(K), -30~40 사이면 섭씨(℃)입니다.")
            else:
                print(f"   💡 [바람 판정힌트] 값이 -40~40 m/s 범위 내에 예쁘게 들어오는지 확인하세요.")
            print("-" * 60)

print("\n======================================================================")
print("🔍 [LDAPS 고고도 변수 검증] 지상 50m 바람 및 Wind Shear")
print("======================================================================\n")

if 'ldaps_train' in globals() and not ldaps_train.empty:
    ldaps_check_cols = [
        'heightAboveGround_50_50MUmax', 'heightAboveGround_50_50MUmin',
        'heightAboveGround_5_XBLWS', 'heightAboveGround_5_YBLWS'
    ]
    
    for col in ldaps_check_cols:
        if col in ldaps_train.columns:
            c_min = ldaps_train[col].min()
            c_max = ldaps_train[col].max()
            c_mean = ldaps_train[col].mean()
            c_null = ldaps_train[col].isnull().sum()
            print(f"▶ 컬럼명: {col}")
            print(f"   - 범위  : {c_min:.4f} ~ {c_max:.4f} (평균: {c_mean:.4f})")
            print(f"   - 결측치: {c_null}개")
            print("-" * 60)
# Out:
# ======================================================================
# 🔍 [GFS 고고도 변수 검증] 지상 80m/100m 바람 및 상층 기온
# ======================================================================
#
# ▶ 컬럼명: heightAboveGround_80_u
#    - 범위  : -21.8138 ~ 25.6597 (평균: 1.9280)
#    - 결측치: 0개
#    💡 [바람 판정힌트] 값이 -40~40 m/s 범위 내에 예쁘게 들어오는지 확인하세요.
# ------------------------------------------------------------
# ▶ 컬럼명: heightAboveGround_80_v
#    - 범위  : -30.7273 ~ 19.6237 (평균: 0.2226)
#    - 결측치: 0개
#    💡 [바람 판정힌트] 값이 -40~40 m/s 범위 내에 예쁘게 들어오는지 확인하세요.
# ------------------------------------------------------------
# ▶ 컬럼명: heightAboveGround_100_100u
#    - 범위  : -22.4202 ~ 27.1495 (평균: 2.0256)
#    - 결측치: 0개
#    💡 [바람 판정힌트] 값이 -40~40 m/s 범위 내에 예쁘게 들어오는지 확인하세요.
# ------------------------------------------------------------
# ▶ 컬럼명: heightAboveGround_100_100v
#    - 범위  : -31.5098 ~ 20.1127 (평균: 0.2285)
#    - 결측치: 0개
#    💡 [바람 판정힌트] 값이 -40~40 m/s 범위 내에 예쁘게 들어오는지 확인하세요.
# ------------------------------------------------------------
# ▶ 컬럼명: isobaricInhPa_850_t
#    - 범위  : 247.1055 ~ 297.8268 (평균: 279.1217)
#    - 결측치: 0개
#    💡 [기온 판정힌트] 평균이 250~300 사이면 캘빈(K), -30~40 사이면 섭씨(℃)입니다.
# ------------------------------------------------------------
#
# ======================================================================
# 🔍 [LDAPS 고고도 변수 검증] 지상 50m 바람 및 Wind Shear
# ======================================================================
#
# ▶ 컬럼명: heightAboveGround_50_50MUmax
#    - 범위  : -17.2054 ~ 29.1335 (평균: 4.6964)
#    - 결측치: 0개
# ------------------------------------------------------------
# ▶ 컬럼명: heightAboveGround_50_50MUmin
#    - 범위  : -19.5501 ~ 27.4754 (평균: 3.6054)
#    - 결측치: 0개
# ------------------------------------------------------------
# ▶ 컬럼명: heightAboveGround_5_XBLWS
#    - 범위  : -0.5354 ~ 0.9574 (평균: 0.0249)
#    - 결측치: 0개
# ------------------------------------------------------------
# ▶ 컬럼명: heightAboveGround_5_YBLWS
#    - 범위  : -6.4863 ~ 3.7117 (평균: 0.0603)
#    - 결측치: 0개
# ------------------------------------------------------------

# %%
# === [독립 실행용] 강수/적설/구름/복사 에너지 단위 검증 스캐너 ===
print("======================================================================")
print("🔍 [LDAPS/GFS 환경 변수 검증] 강수, 적설 및 대기 불안정도")
print("======================================================================\n")

# 1. LDAPS 강수 및 적설 변수 스캔
if 'ldaps_train' in globals() and not ldaps_train.empty:
    ldaps_env_cols = ['surface_0_avg_lsprate', 'surface_0_ncpcp', 'surface_0_snol', 'etc_0_blh']
    print("📂 [LDAPS 원본 데이터 스케일]")
    for col in ldaps_env_cols:
        if col in ldaps_train.columns:
            print(f"▶ {col} -> 범위: {ldaps_train[col].min():.4f} ~ {ldaps_train[col].max():.4f} | 결측: {ldaps_train[col].isnull().sum()}개")
    print("-" * 70)

# 2. GFS 복사 및 구름 변수 스캔
if 'gfs_train' in globals() and not gfs_train.empty:
    gfs_env_cols = ['surface_0_dswrf', 'surface_0_prate', 'atmosphere_0_tcc']
    print("📂 [GFS 원본 데이터 스케일]")
    for col in gfs_env_cols:
        if col in gfs_train.columns:
            print(f"▶ {col} -> 범위: {gfs_train[col].min():.4f} ~ {gfs_train[col].max():.4f} | 결측: {gfs_train[col].isnull().sum()}개")
# Out:
# ======================================================================
# 🔍 [LDAPS/GFS 환경 변수 검증] 강수, 적설 및 대기 불안정도
# ======================================================================
#
# 📂 [LDAPS 원본 데이터 스케일]
# ▶ surface_0_avg_lsprate -> 범위: 0.0000 ~ 0.0245 | 결측: 0개
# ▶ surface_0_ncpcp -> 범위: 0.0000 ~ 88.3106 | 결측: 0개
# ▶ surface_0_snol -> 범위: 0.0000 ~ 5.7109 | 결측: 0개
# ▶ etc_0_blh -> 범위: 11.9226 ~ 3850.2060 | 결측: 0개
# ----------------------------------------------------------------------
# 📂 [GFS 원본 데이터 스케일]
# ▶ surface_0_dswrf -> 범위: 0.0000 ~ 938.3200 | 결측: 0개
# ▶ surface_0_prate -> 범위: 0.0000 ~ 0.0091 | 결측: 0개
# ▶ atmosphere_0_tcc -> 범위: 0.0000 ~ 100.0000 | 결측: 0개

# %%
# === [독립 실행용] SCADA 세부 컬럼 및 메타 정보 스캐너 ===
print("==================================================")
print("🔍 [SCADA 데이터셋] 터빈별 실제 컬럼명 스냅샷")
print("==================================================")

if 'scada_vestas' in globals() and not scada_vestas.empty:
    print(f"▶ Vestas SCADA 컬럼 (앞쪽 10개): {list(scada_vestas.columns[:10])}")
if 'scada_unison' in globals() and not scada_unison.empty:
    print(f"▶ Unison SCADA 컬럼 (앞쪽 10개): {list(scada_unison.columns[:10])}\n")

print("==================================================")
print("🔍 [info.xlsx 메타 데이터] 엑셀 시트 및 내용 스캔")
print("==================================================")

try:
    # 대외활동 DACON 데이터 폴더 내 info.xlsx 직접 로드 시도
    info_path = DATA_DIR / "info.xlsx"
    if info_path.exists():
        # Excel 파일의 모든 시트 이름 확인
        xl = pd.ExcelFile(info_path)
        print(f"▶ info.xlsx 발견! 포함된 시트 목록: {xl.sheet_names}\n")
        
        # 첫 번째 시트 상위 5행 출력
        df_info = pd.read_excel(info_path, sheet_name=0)
        print(f"📂 [첫 번째 시트 데이터 구조] 요약:")
        print(df_info.head())
    else:
        print("❌ DATA_DIR 경로 내에 info.xlsx 파일이 존재하지 않습니다. 경로를 확인해 주세요.")
except Exception as e:
    print(f"❌ 엑셀 로드 중 에러 발생 (openpyxl 라이브러리 필요 등): {e}")
# Out:
# ==================================================
# 🔍 [SCADA 데이터셋] 터빈별 실제 컬럼명 스냅샷
# ==================================================
# ▶ Vestas SCADA 컬럼 (앞쪽 10개): ['kst_dtm', 'vestas_wtg01_power_kw10m', 'vestas_wtg02_power_kw10m', 'vestas_wtg03_power_kw10m', 'vestas_wtg04_power_kw10m', 'vestas_wtg05_power_kw10m', 'vestas_wtg06_power_kw10m', 'vestas_wtg07_power_kw10m', 'vestas_wtg08_power_kw10m', 'vestas_wtg09_power_kw10m']
# ▶ Unison SCADA 컬럼 (앞쪽 10개): ['kst_dtm', 'unison_wtg01_power_kw10m', 'unison_wtg02_power_kw10m', 'unison_wtg03_power_kw10m', 'unison_wtg04_power_kw10m', 'unison_wtg05_power_kw10m', 'unison_wtg01_ws', 'unison_wtg02_ws', 'unison_wtg03_ws', 'unison_wtg04_ws']
#
# ==================================================
# 🔍 [info.xlsx 메타 데이터] 엑셀 시트 및 내용 스캔
# ==================================================
# ▶ info.xlsx 발견! 포함된 시트 목록: ['info']
#
# 📂 [첫 번째 시트 데이터 구조] 요약:
#    Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5                    Unnamed: 6 Unnamed: 7     Unnamed: 8         Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0         NaN  태백가덕산풍력발전 정보        NaN        NaN        NaN        NaN                           NaN        NaN            NaN                NaN         NaN         NaN
# 1         NaN           NaN        NaN        NaN        NaN        NaN                           NaN        NaN            NaN                NaN         NaN         NaN
# 2         NaN            단계         명칭        제작사        모델명         호기                    좌표(Google)      KPX그룹  Hub Height(m)  Rotor Diameter(m)    설비용량(MW)  그룹설비용량(MW)
# 3         NaN             1      태백가덕산     VESTAS       V126          1  37°16'55.61"N 128°57'02.10"E          1            117                126         3.6        21.6
# 4         NaN             1      태백가덕산     VESTAS       V126          2  37°17'04.05"N 128°56'58.35"E        NaN            117                126         3.6         NaN

# %%
# === [독립 실행용] SCADA 데이터셋 전체 컬럼명 전수 스캐너 ===
print("======================================================================")
print("🔍 [Vestas SCADA] 전체 컬럼명 리스트 (총 41개)")
print("======================================================================\n")

if 'scada_vestas' in globals() and not scada_vestas.empty:
    vestas_cols = sorted(list(scada_vestas.columns))
    print(f"▶ 전체 컬럼 개수: {len(vestas_cols)}개")
    print("-" * 70)
    # 한 줄에 너무 길게 나오지 않도록 5개씩 끊어서 출력
    for i in range(0, len(vestas_cols), 5):
        print(vestas_cols[i:i+5])

print("\n======================================================================")
print("🔍 [Unison SCADA] 전체 컬럼명 리스트 (총 20개)")
print("======================================================================\n")

if 'scada_unison' in globals() and not scada_unison.empty:
    unison_cols = sorted(list(scada_unison.columns))
    print(f"▶ 전체 컬럼 개수: {len(unison_cols)}개")
    print("-" * 70)
    for i in range(0, len(unison_cols), 5):
        print(unison_cols[i:i+5])
# Out:
# ======================================================================
# 🔍 [Vestas SCADA] 전체 컬럼명 리스트 (총 41개)
# ======================================================================
#
# ▶ 전체 컬럼 개수: 38개
# ----------------------------------------------------------------------
# ['kst_dtm', 'turbine_ws_mean_calc', 'vestas_wtg01_power_kw10m', 'vestas_wtg01_wd', 'vestas_wtg01_ws']
# ['vestas_wtg02_power_kw10m', 'vestas_wtg02_wd', 'vestas_wtg02_ws', 'vestas_wtg03_power_kw10m', 'vestas_wtg03_wd']
# ['vestas_wtg03_ws', 'vestas_wtg04_power_kw10m', 'vestas_wtg04_wd', 'vestas_wtg04_ws', 'vestas_wtg05_power_kw10m']
# ['vestas_wtg05_wd', 'vestas_wtg05_ws', 'vestas_wtg06_power_kw10m', 'vestas_wtg06_wd', 'vestas_wtg06_ws']
# ['vestas_wtg07_power_kw10m', 'vestas_wtg07_wd', 'vestas_wtg07_ws', 'vestas_wtg08_power_kw10m', 'vestas_wtg08_wd']
# ['vestas_wtg08_ws', 'vestas_wtg09_power_kw10m', 'vestas_wtg09_wd', 'vestas_wtg09_ws', 'vestas_wtg10_power_kw10m']
# ['vestas_wtg10_wd', 'vestas_wtg10_ws', 'vestas_wtg11_power_kw10m', 'vestas_wtg11_wd', 'vestas_wtg11_ws']
# ['vestas_wtg12_power_kw10m', 'vestas_wtg12_wd', 'vestas_wtg12_ws']
#
# ======================================================================
# 🔍 [Unison SCADA] 전체 컬럼명 리스트 (총 20개)
# ======================================================================
#
# ▶ 전체 컬럼 개수: 16개
# ----------------------------------------------------------------------
# ['kst_dtm', 'unison_wtg01_power_kw10m', 'unison_wtg01_wd', 'unison_wtg01_ws', 'unison_wtg02_power_kw10m']
# ['unison_wtg02_wd', 'unison_wtg02_ws', 'unison_wtg03_power_kw10m', 'unison_wtg03_wd', 'unison_wtg03_ws']
# ['unison_wtg04_power_kw10m', 'unison_wtg04_wd', 'unison_wtg04_ws', 'unison_wtg05_power_kw10m', 'unison_wtg05_wd']
# ['unison_wtg05_ws']

# %%
# === [독립 실행용] SCADA 실측 데이터 범위 및 단위 전수 스캐너 ===
print("======================================================================")
print("🔍 [Vestas vs Unison] 실측 풍속 및 풍향 스케일 정밀 대조")
print("======================================================================\n")

if 'scada_vestas' in globals() and not scada_vestas.empty:
    print("📂 [Vestas 단지 대표 1호기 실측 통계]")
    print(f"▶ 발전량 (kw10m) 범위: {scada_vestas['vestas_wtg01_power_kw10m'].min()} ~ {scada_vestas['vestas_wtg01_power_kw10m'].max()}")
    print(f"▶ 풍속   (ws)     범위: {scada_vestas['vestas_wtg01_ws'].min()} ~ {scada_vestas['vestas_wtg01_ws'].max()}")
    print(f"▶ 풍향   (wd)     범위: {scada_vestas['vestas_wtg01_wd'].min()} ~ {scada_vestas['vestas_wtg01_wd'].max()}")
    print("-" * 70)

if 'scada_unison' in globals() and not scada_unison.empty:
    print("📂 [Unison 단지 대표 1호기 실측 통계]")
    print(f"▶ 발전량 (kw10m) 범위: {scada_unison['unison_wtg01_power_kw10m'].min()} ~ {scada_unison['unison_wtg01_power_kw10m'].max()}")
    print(f"▶ 풍속   (ws)     범위: {scada_unison['unison_wtg01_ws'].min()} ~ {scada_unison['unison_wtg01_ws'].max()}")
    print(f"▶ 풍향   (wd)     범위: {scada_unison['unison_wtg01_wd'].min()} ~ {scada_unison['unison_wtg01_wd'].max()}")
# Out:
# ======================================================================
# 🔍 [Vestas vs Unison] 실측 풍속 및 풍향 스케일 정밀 대조
# ======================================================================
#
# 📂 [Vestas 단지 대표 1호기 실측 통계]
# ▶ 발전량 (kw10m) 범위: -42512957 ~ 42512957
# ▶ 풍속   (ws)     범위: 0.0 ~ 22.8
# ▶ 풍향   (wd)     범위: 0.0 ~ 359.0
# ----------------------------------------------------------------------
# 📂 [Unison 단지 대표 1호기 실측 통계]
# ▶ 발전량 (kw10m) 범위: 0.0 ~ 800.0
# ▶ 풍속   (ws)     범위: 0.0 ~ 22.16
# ▶ 풍향   (wd)     범위: -179.99800436642 ~ 179.99237027425

# %%
# === [독립 실행용] 예보 풍속 vs 터빈 실측 풍속 오차 분석 스캐너 ===
import pandas as pd
import numpy as np

print("======================================================================")
print("🔍 기상청 예보 풍속 vs 터빈 실측 풍속 상습 오차(Bias) 분포 분석")
print("======================================================================\n")

# Vestas 터빈들의 시간별 전체 평균 실측 풍속 계산
v_ws_cols = [c for c in scada_vestas.columns if '_ws' in c and 'ratio' not in c]
scada_vestas['turbine_ws_mean'] = scada_vestas[v_ws_cols].mean(axis=1)
v_hourly = scada_vestas.groupby('hourly_kst')['turbine_ws_mean'].mean().reset_index()
v_hourly.columns = ['kst_dtm', 'real_ws_mean']

# 기존에 빌드된 final_df와 결합하여 오차 비교 (메모리에 final_df가 있을 때 동작)
if 'final_df' in globals():
    check_df = pd.merge(final_df[['kst_dtm', 'month', 'hour', 'ldaps_ws_mean', 'gfs_ws_mean']], v_hourly, on='kst_dtm', how='inner')
    
    check_df['ldaps_bias'] = check_df['ldaps_ws_mean'] - check_df['real_ws_mean']
    check_df['gfs_bias'] = check_df['gfs_ws_mean'] - check_df['real_ws_mean']
    
    print("📂 [전체 기간 평균 오차 (예보풍속 - 실측풍속)]")
    print(f"▶ LDAPS 평균 오차: {check_df['ldaps_bias'].mean():.4f} m/s")
    print(f"▶ GFS   평균 오차: {check_df['gfs_bias'].mean():.4f} m/s")
    print("-" * 70)
    
    print("📂 [봄/여름철 일부 월별 오차 경향성 샘플]")
    bias_map = check_df.groupby('month')[['ldaps_bias', 'gfs_bias']].mean().head(4)
    print(bias_map)
else:
    print("ℹ️ final_df 가 메모리에 로드되어 있지 않습니다. 3번 셀을 먼저 실행한 뒤 돌려보세요.")
# Out:
# ======================================================================
# 🔍 기상청 예보 풍속 vs 터빈 실측 풍속 상습 오차(Bias) 분포 분석
# ======================================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 12
#      10 v_ws_cols = [c for c in scada_vestas.columns if '_ws' in c and 'ratio' not in c]
#      11 scada_vestas['turbine_ws_mean'] = scada_vestas[v_ws_cols].mean(axis=1)
# ---> 12 v_hourly = scada_vestas.groupby('hourly_kst')['turbine_ws_mean'].mean().reset_index()
#      13 v_hourly.columns = ['kst_dtm', 'real_ws_mean']
#      15 # 기존에 빌드된 final_df와 결합하여 오차 비교 (메모리에 final_df가 있을 때 동작)
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'hourly_kst'

# %%
# === [💡 싱크 보정 완료] VRATE 및 장파복사 변수 범위 정밀 스캐너 ===
print("======================================================================")
print("🔍 [GFS 특수 기상 변수] 환기율(VRATE) 및 장파 복사 정밀 스캔")
print("======================================================================\n")

if 'gfs_train' in globals() and not gfs_train.empty:
    # 🎯 변수명 싱크 수정: 루프 내부 인덱스 c를 정확히 타겟팅하도록 고정
    real_vrate = [c for c in gfs_train.columns if 'VRATE' in c or 'vrate' in c.lower()]
    real_ndnlw = [c for c in gfs_train.columns if 'NDNLW' in c or 'dlwrf' in c.lower() or 'lwrf' in c.lower()]
    
    cols_to_run = real_vrate + real_ndnlw
    
    if not cols_to_run:
        print("⚠ 대상 컬럼을 찾지 못했습니다. GFS 원본 컬럼 중 일부를 직접 지정합니다:")
        # 혹시 모를 누락 방지용 하드코딩 백업
        cols_to_run = [c for c in ['planetaryBoundaryLayer_0_VRATE', 'surface_0_dlwrf'] if c in gfs_train.columns]

    for col in cols_to_run:
        c_min = gfs_train[col].min()
        c_max = gfs_train[col].max()
        c_mean = gfs_train[col].mean()
        c_null = gfs_train[col].isnull().sum()
        print(f"▶ 원본 컬럼명: {col}")
        print(f"   - 데이터 범위: {c_min:.4f} ~ {c_max:.4f} (평균: {c_mean:.4f})")
        print(f"   - 결측치 수  : {c_null}개")
        print("-" * 70)
else:
    print("ℹ GFS Train 데이터가 메모리에 로드되어 있지 않습니다.")
# Out:
# ======================================================================
# 🔍 [GFS 특수 기상 변수] 환기율(VRATE) 및 장파 복사 정밀 스캔
# ======================================================================
#
# ▶ 원본 컬럼명: planetaryBoundaryLayer_0_VRATE
#    - 데이터 범위: 0.0000 ~ 80000.0000 (평균: 3497.8999)
#    - 결측치 수  : 0개
# ----------------------------------------------------------------------
# ▶ 원본 컬럼명: surface_0_dlwrf
#    - 데이터 범위: 128.2634 ~ 447.8611 (평균: 303.3820)
#    - 결측치 수  : 0개
# ----------------------------------------------------------------------

# %%
# === [독립 실행용] info.xlsx 메타 데이터 정밀 스캐너 ===
import pandas as pd
from pathlib import Path

print("======================================================================")
print("🔍 [info.xlsx] 메타 데이터 전체 시트 전수조사 및 구조 스캔")
print("======================================================================\n")

# 데이터 디렉토리 설정 (기존 노트북 변수 활용)
if 'DATA_DIR' in globals():
    info_path = DATA_DIR / "info.xlsx"
else:
    info_path = Path("open/info.xlsx")  # 기본 경로 백업

if info_path.exists():
    try:
        xl = pd.ExcelFile(info_path)
        print(f"📂 발견된 Excel 시트 목록: {xl.sheet_names}\n")
        print("-" * 70)
        
        for sheet in xl.sheet_names:
            df_sheet = pd.read_excel(info_path, sheet_name=sheet)
            print(f"📊 시트명: [{sheet}] | 데이터 크기: {df_sheet.shape}")
            print("▶ 컬럼 목록:", list(df_sheet.columns))
            print("\n상위 3개 행 샘플:")
            print(df_sheet.head(3))
            print("=" * 70)
            
    except Exception as e:
        print(f"❌ 엑셀 파일 로드 중 오류 발생: {e}\n💡 openpyxl 라이브러리가 설치되어 있는지 확인하세요.")
else:
    print(f"❌ 경로에 info.xlsx 파일이 없습니다: {info_path}")
# Out:
# ======================================================================
# 🔍 [info.xlsx] 메타 데이터 전체 시트 전수조사 및 구조 스캔
# ======================================================================
#
# 📂 발견된 Excel 시트 목록: ['info']
#
# ----------------------------------------------------------------------
# 📊 시트명: [info] | 데이터 크기: (20, 12)
# ▶ 컬럼 목록: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11']
#
# 상위 3개 행 샘플:
#    Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7     Unnamed: 8         Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0         NaN  태백가덕산풍력발전 정보        NaN        NaN        NaN        NaN         NaN        NaN            NaN                NaN         NaN         NaN
# 1         NaN           NaN        NaN        NaN        NaN        NaN         NaN        NaN            NaN                NaN         NaN         NaN
# 2         NaN            단계         명칭        제작사        모델명         호기  좌표(Google)      KPX그룹  Hub Height(m)  Rotor Diameter(m)    설비용량(MW)  그룹설비용량(MW)
# ======================================================================

# %%
# === [🥇 동적 헤더 탐색 완공] info.xlsx 무결성 파싱 스캐너 ===
import pandas as pd
import re

if 'DATA_DIR' in globals():
    info_path = DATA_DIR / "info.xlsx"
else:
    info_path = "open/info.xlsx"

try:
    # 1. 헤더 없이 원본 엑셀을 통째로 로드 (None 지정)
    df_raw = pd.read_excel(info_path, sheet_name=0, header=None)
    
    # 2. 행 전체를 돌며 '명칭'과 '제작사'라는 단어가 동시에 존재하는 진짜 헤더 행 찾기
    header_idx = None
    for idx, row in df_raw.iterrows():
        row_vals = [str(val).strip() for val in row.values if pd.notna(val)]
        if '명칭' in row_vals and '제작사' in row_vals:
            header_idx = idx
            break
            
    if header_idx is None:
        raise ValueError("엑셀 데이터 내부에서 '명칭' 컬럼 헤더 행을 찾을 수 없습니다.")
        
    # 3. 찾아낸 헤더 행을 기준으로 데이터프레임 재정렬
    columns_cleaned = [str(c).strip() for c in df_raw.iloc[header_idx].values]
    df_clean_info = pd.DataFrame(df_raw.iloc[header_idx+1:].values, columns=columns_cleaned)
    
    # '명칭' 컬럼이 유효한 데이터 행만 필터링
    df_clean_info = df_clean_info[df_clean_info['명칭'].notna() & (df_clean_info['명칭'] != 'NaN')].reset_index(drop=True)
    
    # 4. 구글 DMS 좌표 분리/변환 함수
    def parse_dms(dms_str):
        if pd.isna(dms_str) or str(dms_str).strip() == 'nan': return None, None
        try:
            parts = re.findall(r'[-+]?\d*\.\d+|\d+|N|E', str(dms_str))
            if len(parts) >= 8:
                lat = float(parts[0]) + float(parts[1])/60 + float(parts[2])/3600
                lon = float(parts[4]) + float(parts[5])/60 + float(parts[6])/3600
                return round(lat, 6), round(lon, 6)
        except:
            pass
        return None, None

    # 좌표 변환 적용
    coords = df_clean_info['좌표(Google)'].apply(parse_dms)
    df_clean_info['lat'] = [c[0] for c in coords]
    df_clean_info['lon'] = [c[1] for c in coords]

    print("======================================================================")
    print("🥇 [동적 정제 완공] 태백가덕산 풍력 단지 터빈별 정밀 마스터 테이블")
    print("======================================================================\n")
    print(f"▶ 전체 파싱된 터빈 수: {len(df_clean_info)}기")
    print("-" * 80)
    
    # 가독성을 위해 필수 정보만 출력
    display_cols = [c for c in ['단계', '명칭', '제작사', '호기', 'KPX그룹', 'lat', 'lon', '설비용량(MW)'] if c in df_clean_info.columns]
    print(df_clean_info[display_cols].to_string(index=False))
    
except Exception as e:
    print(f"❌ 파싱 중 에러 발생: {e}")
# Out:
# ======================================================================
# 🥇 [동적 정제 완공] 태백가덕산 풍력 단지 터빈별 정밀 마스터 테이블
# ======================================================================
#
# ▶ 전체 파싱된 터빈 수: 17기
# --------------------------------------------------------------------------------
# 단계    명칭    제작사 호기 KPX그룹       lat        lon 설비용량(MW)
#  1 태백가덕산 VESTAS  1     1 37.282114 128.950583      3.6
#  1 태백가덕산 VESTAS  2   NaN 37.284458 128.949542      3.6
#  1 태백가덕산 VESTAS  3   NaN 37.286525 128.949719      3.6
#  1 태백가덕산 VESTAS  4   NaN 37.289753 128.951022      3.6
#  1 태백가덕산 VESTAS  5   NaN 37.291167 128.954328      3.6
#  1 태백가덕산 VESTAS  6   NaN 37.288744 128.956933      3.6
#  1 태백가덕산 VESTAS  7     2 37.287833 128.959631      3.6
#  1 태백가덕산 VESTAS  8   NaN 37.286469 128.963122      3.6
#  1 태백가덕산 VESTAS  9   NaN 37.283603 128.965956      3.6
#  1 태백가덕산 VESTAS 10   NaN 37.281325 128.967828      3.6
#  1 태백가덕산 VESTAS 11   NaN 37.279136 128.966978      3.6
#  1 태백가덕산 VESTAS 12   NaN 37.275161 128.967372      3.6
#  2 태백가덕산 UNISON  1     3 37.283258 128.962492      4.2
#  2  태백원동 UNISON  2   NaN 37.277892 128.970500      4.2
#  2  태백원동 UNISON  3   NaN 37.274453 128.972928      4.2
#  2  태백원동 UNISON  4   NaN 37.271828 128.974725      4.2
#  2  태백원동 UNISON  5   NaN 37.268564 128.976578      4.2

# %%
# === [독립 실행용] NWP 격자 고유 ID 및 공간 좌표 범위 스캐너 ===
print("======================================================================")
print("🔍 [LDAPS 격자 전수조사] 고유 Grid ID 및 위·경도 공간 범위")
print("======================================================================\n")

if 'ldaps_train' in globals() and not ldaps_train.empty:
    # 중복 제거한 고유 격자 목록 추출
    ldaps_grids = ldaps_train[['grid_id', 'latitude', 'longitude']].drop_duplicates().sort_values('grid_id').reset_index(drop=True)
    print(f"▶ LDAPS 고유 격자 개수 : {len(ldaps_grids)}개")
    if len(ldaps_grids) > 0:
        print(f"▶ 격자 ID 범위        : {ldaps_grids['grid_id'].min()} ~ {ldaps_grids['grid_id'].max()}")
        print(f"▶ 위도(Latitude) 범위  : {ldaps_grids['latitude'].min():.6f}°N ~ {ldaps_grids['latitude'].max():.6f}°N")
        print(f"▶ 경도(Longitude) 범위 : {ldaps_grids['longitude'].min():.6f}°E ~ {ldaps_grids['longitude'].max():.6f}°E")
        print("\n📂 [LDAPS 격자 상위 5개 좌표 샘플]:")
        print(ldaps_grids.head(5).to_string(index=False))
else:
    print("ℹ LDAPS Train 데이터가 메모리에 로드되어 있지 않습니다.")

print("\n======================================================================")
print("🔍 [GFS 격자 전수조사] 고유 Grid ID 및 위·경도 공간 범위")
print("======================================================================\n")

if 'gfs_train' in globals() and not gfs_train.empty:
    gfs_grids = gfs_train[['grid_id', 'latitude', 'longitude']].drop_duplicates().sort_values('grid_id').reset_index(drop=True)
    print(f"▶ GFS 고유 격자 개수   : {len(gfs_grids)}개")
    if len(gfs_grids) > 0:
        print(f"▶ 격자 ID 범위        : {gfs_grids['grid_id'].min()} ~ {gfs_grids['grid_id'].max()}")
        print(f"▶ 위도(Latitude) 범위  : {gfs_grids['latitude'].min():.6f}°N ~ {gfs_grids['latitude'].max():.6f}°N")
        print(f"▶ 경도(Longitude) 범위 : {gfs_grids['longitude'].min():.6f}°E ~ {gfs_grids['longitude'].max():.6f}°E")
        print("\n📂 [GFS 격자 상위 5개 좌표 샘플]:")
        print(gfs_grids.head(5).to_string(index=False))
else:
    print("ℹ GFS Train 데이터가 메모리에 로드되어 있지 않습니다.")
# Out:
# ======================================================================
# 🔍 [LDAPS 격자 전수조사] 고유 Grid ID 및 위·경도 공간 범위
# ======================================================================
#
# ▶ LDAPS 고유 격자 개수 : 16개
# ▶ 격자 ID 범위        : 1 ~ 16
# ▶ 위도(Latitude) 범위  : 37.260700°N ~ 37.303200°N
# ▶ 경도(Longitude) 범위 : 128.925700°E ~ 128.995800°E
#
# 📂 [LDAPS 격자 상위 5개 좌표 샘플]:
#  grid_id  latitude  longitude
#        1   37.3032   128.9443
#        2   37.3027   128.9617
#        3   37.3022   128.9790
#        4   37.2899   128.9263
#        5   37.2894   128.9437
#
# ======================================================================
# 🔍 [GFS 격자 전수조사] 고유 Grid ID 및 위·경도 공간 범위
# ======================================================================
#
# ▶ GFS 고유 격자 개수   : 9개
# ▶ 격자 ID 범위        : 1 ~ 9
# ▶ 위도(Latitude) 범위  : 37.000000°N ~ 37.500000°N
# ▶ 경도(Longitude) 범위 : 128.750000°E ~ 129.250000°E
#
# 📂 [GFS 격자 상위 5개 좌표 샘플]:
#  grid_id  latitude  longitude
#        1     37.50     128.75
#        2     37.50     129.00
#        3     37.50     129.25
#        4     37.25     128.75
#        5     37.25     129.00

# %%
# === [독립 실행용] 단지별 1:1 매핑 수석 격자점 역추적 스캐너 ===
import pandas as pd
import numpy as np

# 하버사인 지구 거리 계산 함수
def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371.0  # 지구 반지름 (km)
    phi1, phi2 = np.radians(lat1), np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi/2)**2 + np.cos(phi1)*np.cos(phi2)*np.sin(delta_lambda/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c

print("======================================================================")
print("🎯 [공간 매핑 매칭 리포트] 각 KPX 그룹별 최적 수석 격자 ID 추적")
print("======================================================================\n")

# 1. 이전 단계에서 정제된 df_clean_info의 KPX그룹 병합 셀 결측 처리 적용
df_meta = df_clean_info.copy()
df_meta['KPX그룹'] = df_meta['KPX그룹'].ffill().astype(int)

# 2. 그룹별 터빈 중심 좌표 도출
group_centers = df_meta.groupby('KPX그룹')[['lat', 'lon']].mean().reset_index()

# 3. 메모리의 NWP 고유 격자 좌표 로드 후 매칭
if 'ldaps_train' in globals() and 'gfs_train' in globals():
    ldaps_grids = ldaps_train[['grid_id', 'latitude', 'longitude']].drop_duplicates().reset_index(drop=True)
    gfs_grids = gfs_train[['grid_id', 'latitude', 'longitude']].drop_duplicates().reset_index(drop=True)
    
    for _, g_row in group_centers.iterrows():
        g_id = int(g_row['KPX그룹'])
        c_lat, c_lon = g_row['lat'], g_row['lon']
        print(f"🏢 [KPX 그룹 {g_id} 단지 중심 좌표] : 위도 {c_lat:.5f}°N | 경도 {c_lon:.5f}°E")
        
        # LDAPS 최근접 탐색
        ldaps_grids['dist'] = haversine_distance(c_lat, c_lon, ldaps_grids['latitude'], ldaps_grids['longitude'])
        best_ldaps = ldaps_grids.sort_values('dist').iloc[0]
        print(f"   ▶ 최적 매핑 LDAPS 격자: ID [{int(best_ldaps['grid_id'])}] (거리: {best_ldaps['dist']:.3f} km)")
        
        # GFS 최근접 탐색
        gfs_grids['dist'] = haversine_distance(c_lat, c_lon, gfs_grids['latitude'], gfs_grids['longitude'])
        best_gfs = gfs_grids.sort_values('dist').iloc[0]
        print(f"   ▶ 최적 매핑 GFS   격자: ID [{int(best_gfs['grid_id'])}] (거리: {best_gfs['dist']:.3f} km)\n")
else:
    print("ℹ 기상 데이터가 로드되어 있지 않습니다. 3번 셀을 구동한 뒤 확인하세요.")
# Out:
# ======================================================================
# 🎯 [공간 매핑 매칭 리포트] 각 KPX 그룹별 최적 수석 격자 ID 추적
# ======================================================================
#
# 🏢 [KPX 그룹 1 단지 중심 좌표] : 위도 37.28713°N | 경도 128.95202°E
#    ▶ 최적 매핑 LDAPS 격자: ID [5] (거리: 0.778 km)
#    ▶ 최적 매핑 GFS   격자: ID [5] (거리: 5.922 km)
#
# 🏢 [KPX 그룹 2 단지 중심 좌표] : 위도 37.28225°N | 경도 128.96515°E
#    ▶ 최적 매핑 LDAPS 격자: ID [6] (거리: 0.815 km)
#    ▶ 최적 매핑 GFS   격자: ID [5] (거리: 4.730 km)
#
# 🏢 [KPX 그룹 3 단지 중심 좌표] : 위도 37.27520°N | 경도 128.97144°E
#    ▶ 최적 매핑 LDAPS 격자: ID [12] (거리: 0.568 km)
#    ▶ 최적 매핑 GFS   격자: ID [5] (거리: 3.773 km)

# %%
# === [독립 실행용] SCADA 터빈별 실측 전력 범위 정밀 스캐너 ===
print("======================================================================")
print("🔍 [VESTAS SCADA 원본] 호기별 전력(power_kw10m) 통계 및 최대치 스캔")
print("======================================================================\n")

if 'scada_vestas' in globals() and not scada_vestas.empty:
    v_wtgs = [f'wtg{i:02d}' for i in range(1, 13)]
    v_summary = []
    for wtg in v_wtgs:
        p_col = f'vestas_{wtg}_power_kw10m'
        if p_col in scada_vestas.columns:
            p_max = scada_vestas[p_col].max()
            p_min = scada_vestas[p_col].min()
            p_mean = scada_vestas[p_col].mean()
            # 정격 3.6MW(3600kW) 대비 비정상적으로 튀는 데이터 비율 계산 (예시 임계치 5000)
            over_scale = (scada_vestas[p_col] > 5000).sum()
            v_summary.append([wtg, p_min, p_max, p_mean, over_scale])
    
    df_v_sum = pd.DataFrame(v_summary, columns=['호기', '최소값', '최대값', '평균값', '5000 초과 건수'])
    print(df_v_sum.to_string(index=False))
else:
    print("ℹ scada_vestas 데이터가 메모리에 로드되어 있지 않습니다.")

print("\n======================================================================")
print("🔍 [UNISON SCADA 원본] 호기별 전력(power_kw10m) 통계 및 최대치 스캔")
print("======================================================================\n")

if 'scada_unison' in globals() and not scada_unison.empty:
    u_wtgs = [f'wtg{i:02d}' for i in range(1, 6)]
    u_summary = []
    for wtg in u_wtgs:
        p_col = f'unison_{wtg}_power_kw10m'
        if p_col in scada_unison.columns:
            p_max = scada_unison[p_col].max()
            p_min = scada_unison[p_col].min()
            p_mean = scada_unison[p_col].mean()
            over_scale = (scada_unison[p_col] > 6000).sum()
            u_summary.append([wtg, p_min, p_max, p_mean, over_scale])
            
    df_u_sum = pd.DataFrame(u_summary, columns=['호기', '최소값', '최대값', '평균값', '6000 초과 건수'])
    print(df_u_sum.to_string(index=False))
else:
    print("ℹ scada_unison 데이터가 메모리에 로드되어 있지 않습니다.")
# Out:
# ======================================================================
# 🔍 [VESTAS SCADA 원본] 호기별 전력(power_kw10m) 통계 및 최대치 스캔
# ======================================================================
#
#    호기  최소값   최대값        평균값  5000 초과 건수
# wtg01  0.0 602.0 196.092425           0
# wtg02  0.0 602.0 201.886833           0
# wtg03  0.0 602.0 218.044621           0
# wtg04  0.0 602.0 187.209833           0
# wtg05  0.0 602.0 153.784045           0
# wtg06  0.0 602.0 158.814094           0
# wtg07  0.0 602.0 139.233875           0
# wtg08  0.0 602.0 186.963751           0
# wtg09  0.0 602.0 199.973738           0
# wtg10  0.0 602.0 239.782033           0
# wtg11  0.0 602.0 223.643386           0
# wtg12  0.0 602.0 199.475755           0
#
# ======================================================================
# 🔍 [UNISON SCADA 원본] 호기별 전력(power_kw10m) 통계 및 최대치 스캔
# ======================================================================
#
#    호기  최소값    최대값        평균값  6000 초과 건수
# wtg01  0.0  800.0 162.753741           0
# wtg02  0.0 1000.0 145.411022           0
# wtg03  0.0  900.0 201.070268           0
# wtg04  0.0  800.0 196.390233           0
# wtg05  0.0  800.0 221.543216           0
